# %%
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager 
from selenium.webdriver.common.by import By
import pandas as pd
import time

# %%
driver=webdriver.Chrome(executable_path="C:\\BrowserDrivers\\chromedriver.exe")
driver.get("https://www.naukri.com/full-stack-development-jobs?k=full%20stack%20development&nignbevent_src=jobsearchDeskGNB")
job_elements = driver.find_elements(By.TAG_NAME,'a')
job_desc=[]
for i in job_elements:
    if i.get_attribute('class')=="title ellipsis":
        print(i.text)
        print(i.get_attribute('href'))
        job_desc.append([i.text,i.get_attribute('href')])
#driver.close()
# Out:
# C:\Users\chaitu\AppData\Local\Temp/ipykernel_3660/1220136570.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver=webdriver.Chrome(executable_path="C:\\BrowserDrivers\\chromedriver.exe")

# %%
len(job_desc)
# Out:
# 20

# %%
driver=webdriver.Chrome(executable_path="C:\\BrowserDrivers\\chromedriver.exe")
driver.get("https://www.naukri.com/full-stack-development-jobs-2?k=full%20stack%20development&nignbevent_src=jobsearchDeskGNB")
page_2=driver.find_elements(By.TAG_NAME,'a')
for i in page_2:
    if i.get_attribute('class')=="title ellipsis":
        print(i.text)
        print(i.get_attribute('href'))
        job_desc.append([i.text,i.get_attribute('href')])
#driver.close()
# Out:
# C:\Users\chaitu\AppData\Local\Temp/ipykernel_3660/3078046691.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver=webdriver.Chrome(executable_path="C:\\BrowserDrivers\\chromedriver.exe")
# Technical Lead - Full Stack Development
# https://www.naukri.com/job-listings-technical-lead-full-stack-development-serving-skill-noida-5-to-10-years-310123916266
# AWS Architect - Full Stack Development
# https://www.naukri.com/job-listings-aws-architect-full-stack-development-serving-skill-bangalore-bengaluru-10-to-14-years-310123916053
# Tech Lead - Full Stack Development - Java
# https://www.naukri.com/job-listings-tech-lead-full-stack-development-java-serving-skill-noida-8-to-12-years-310123915858
# Software Engineer - Full Stack Development - JavaScript/Node.js
# https://www.naukri.com/job-listings-software-engineer-full-stack-development-javascript-node-js-huquo-consulting-gurgaon-gurugram-3-to-6-years-310123912082
# Software Architect - Full Stack Development - PHP / Python
# https://www.naukri.com/job-listings-software-architect-full-stack-development-php-python-imindyourbusiness-bangalore-bengaluru-indiranagar-8-to-12-years-310123908217
# Azure with Full Stack Development & Senior Developer
# https://www.naukri.com/job-listings-azure-with-full-stack-development-senior-developer-cliqhr-pune-6-to-9-years-300323904353
# Technical Lead - Full Stack Development - Python / JavaScript
# https://www.naukri.com/job-listings-technical-lead-full-stack-development-python-javascript-talent-acceleration-corridor-gurgaon-gurugram-4-to-6-years-281222910409
# Head of Technology - Full Stack Development
# https://www.naukri.com/job-listings-head-of-technology-full-stack-development-hyrezy-talent-solution-gurgaon-gurugram-6-to-11-years-281222906712
# Technical Lead - Full Stack Development - Node.js / React.js
# https://www.naukri.com/job-listings-technical-lead-full-stack-development-node-js-react-js-hyrezy-talent-solution-chennai-5-to-10-years-281222906616
# Senior Software Engineer - Full Stack Development
# https://www.naukri.com/job-listings-senior-software-engineer-full-stack-development-hyrezy-talent-solutions-mumbai-3-to-5-years-280323907373
# Senior Software Engineer - Full Stack Development - React.js/TypeScrip
# https://www.naukri.com/job-listings-senior-software-engineer-full-stack-development-react-js-typescrip-hyrezy-talent-solutions-mumbai-3-to-5-years-280323907370
# Tech Lead - Full Stack Development
# https://www.naukri.com/job-listings-tech-lead-full-stack-development-hyrezy-talent-solutions-mumbai-8-to-10-years-280323907274
# Technical Lead - Full Stack Development - Node.js / React.js
# https://www.naukri.com/job-listings-technical-lead-full-stack-development-node-js-react-js-hyrezy-talent-solutions-chennai-5-to-10-years-280323907153
# Tech Lead - Full Stack Development - Entertainment Domain
# https://www.naukri.com/job-listings-tech-lead-full-stack-development-entertainment-domain-hyrezy-talent-solutions-mumbai-8-to-10-years-280323907030
# Technical Lead - Full Stack Development - Node.js/React.js
# https://www.naukri.com/job-listings-technical-lead-full-stack-development-node-js-react-js-hyrezy-talent-solutions-chennai-6-to-11-years-280323906829
# Software Engineer - Full Stack Development - JavaScript/Node.js
# https://www.naukri.com/job-listings-software-engineer-full-stack-development-javascript-node-js-huquo-consulting-gurgaon-gurugram-3-to-6-years-280323905955
# Co-Founder/Chief Technology Officer - Full Stack Development
# https://www.naukri.com/job-listings-co-founder-chief-technology-officer-full-stack-development-benovymed-healthcare-gurgaon-gurugram-delhi-ncr-2-to-7-years-280323904850
# Vice President - Full Stack Development
# https://www.naukri.com/job-listings-vice-president-full-stack-development-benovymed-healthcare-delhi-ncr-8-to-12-years-280323904847
# Head of Technology - Full Stack Development
# https://www.naukri.com/job-listings-head-of-technology-full-stack-development-hyrezy-talent-solutions-gurgaon-gurugram-6-to-11-years-280323904524
# Tech Lead - Full Stack Development - Entertainment Domain
# https://www.naukri.com/job-listings-tech-lead-full-stack-development-entertainment-domain-hyrezy-talent-solutions-mumbai-8-to-10-years-280323904166

# %%
len(job_desc)
# Out:
# 40

# %%
from selenium.common.exceptions import NoSuchElementException
a=[]
k=0
for i in job_desc:
    driver=webdriver.Chrome(executable_path='C:\\BrowserDrivers\\chromedriver.exe')
    driver.get(i[1])
    try:
        exp_name=driver.find_element(By.CSS_SELECTOR,"div[class='exp'] span")
        a.append(exp_name.text)
    except NoSuchElementException:
        class_name=driver.find_element(By.CLASS_NAME,"slide-meta-exp")
        a.append(class_name.text)
    driver.close()
# Out:
# C:\Users\chaitu\AppData\Local\Temp/ipykernel_3660/1320582177.py:5: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver=webdriver.Chrome(executable_path='C:\\BrowserDrivers\\chromedriver.exe')

# %%
len(a)
# Out:
# 40

# %%
k=0
for i in a:
    job_desc[k].append(i)
    k=k+1

# %%
job_desc
# Out:
# [['Chief Technology Officer/Vice President - Full Stack Development',
#   'https://www.naukri.com/job-listings-chief-technology-officer-vice-president-full-stack-development-benovymed-healthcare-noida-gurgaon-gurugram-delhi-ncr-2-to-7-years-190423904791',
#   '2 - 7 years'],
#  ['Engineering Lead - Full Stack Development',
#   'https://www.naukri.com/job-listings-engineering-lead-full-stack-development-prime-infosoft-kolkata-mumbai-hyderabad-secunderabad-lucknow-chennai-ahmedabad-bangalore-bengaluru-delhi-ncr-10-to-12-years-301222909681',
#   '10 - 12 years'],
#  ['Tech Lead/CTO - Full Stack Development - Web & Mobile Apps',
#   'https://www.naukri.com/job-listings-tech-lead-cto-full-stack-development-web-mobile-apps-emploi-consultancy-madhya-pradesh-5-to-7-years-281222906319',
#   '5 - 7 years'],
#  ['Engineering Lead - Full Stack Development',
#   'https://www.naukri.com/job-listings-engineering-lead-full-stack-development-prime-infosoft-kolkata-mumbai-hyderabad-secunderabad-chennai-gurgaon-gurugram-delhi-ncr-bangalore-bengaluru-10-to-12-years-281222905772',
#   '10 - 12 years'],
#  ['Software Architect - Full Stack Development',
#   'https://www.naukri.com/job-listings-software-architect-full-stack-development-imindyourbusiness-bangalore-bengaluru-7-to-10-years-280223911401',
#   '7 - 10 years'],
#  ['Software Engineer- Full Stack Development- Javascript/Node.js/React.js',
#   'https://www.naukri.com/job-listings-software-engineer-full-stack-development-javascript-node-js-react-js-huquo-consulting-pvt-ltd-gurgaon-gurugram-3-to-6-years-271222911597',
#   '3 - 6 years'],
#  ['Senior Software Engineer - Full Stack Development',
#   'https://www.naukri.com/job-listings-senior-software-engineer-full-stack-development-career-infosystem-kolkata-mumbai-hyderabad-secunderabad-lucknow-chennai-ahmedabad-bangalore-bengaluru-delhi-ncr-5-to-8-years-220123901870',
#   '5 - 8 years'],
#  ['Team Lead - Full Stack Development',
#   'https://www.naukri.com/job-listings-team-lead-full-stack-development-ks-smart-solutions-chennai-5-to-8-years-210223906308',
#   '5 - 8 years'],
#  ['Software Engineer - Full Stack Development',
#   'https://www.naukri.com/job-listings-software-engineer-full-stack-development-ks-smart-solutions-chennai-2-to-4-years-210223905990',
#   '2 - 4 years'],
#  ['Full Stack Development',
#   'https://www.naukri.com/job-listings-full-stack-development-legitbytes-mohali-1-to-4-years-170423500061',
#   '1 - 4 years'],
#  ['Technical Lead - Full Stack Development',
#   'https://www.naukri.com/job-listings-technical-lead-full-stack-development-okda-solutions-hyderabad-secunderabad-8-to-12-years-160423900870',
#   '8 - 12 years'],
#  ['Software Architect - Full Stack Development - PHP/Python',
#   'https://www.naukri.com/job-listings-software-architect-full-stack-development-php-python-imindyourbusiness-bangalore-bengaluru-8-to-12-years-120423907913',
#   '8 - 12 years'],
#  ['Technical Lead - Full Stack Development - Python / JavaScript',
#   'https://www.naukri.com/job-listings-technical-lead-full-stack-development-python-javascript-talent-acceleration-corridor-gurgaon-gurugram-4-to-8-years-310323904875',
#   '4 - 8 years'],
#  ['Senior Technical Consultant - Full Stack Development',
#   'https://www.naukri.com/job-listings-senior-technical-consultant-full-stack-development-talent-acceleration-corridor-gurgaon-gurugram-12-to-15-years-310323904847',
#   '12 - 15 years'],
#  ['Technical Lead - Full Stack Development',
#   'https://www.naukri.com/job-listings-technical-lead-full-stack-development-smart4talent-gurgaon-gurugram-12-to-18-years-310323904749',
#   '12 - 18 years'],
#  ['Senior Software Engineer - Full Stack Development',
#   'https://www.naukri.com/job-listings-senior-software-engineer-full-stack-development-thinkapps-solutions-mumbai-navi-mumbai-3-to-5-years-310323904710',
#   '3 - 5 years'],
#  ['Technical Lead I - Full Stack Development - .Net',
#   'https://www.naukri.com/job-listings-technical-lead-i-full-stack-development-net-thinkapps-solutions-noida-mumbai-hyderabad-secunderabad-pune-chennai-bangalore-bengaluru-7-to-10-years-310323904705',
#   '7 - 10 years'],
#  ['Lead/Principal Software Engineer - Full Stack Development',
#   'https://www.naukri.com/job-listings-lead-principal-software-engineer-full-stack-development-thinkapps-solutions-mumbai-6-to-11-years-310323904683',
#   '6 - 11 years'],
#  ['Technical Lead II - Full Stack Development - Java/AWS/Spring Boot',
#   'https://www.naukri.com/job-listings-technical-lead-ii-full-stack-development-java-aws-spring-boot-thinkapps-solutions-noida-mumbai-hyderabad-secunderabad-pune-chennai-bangalore-bengaluru-7-to-10-years-310323904649',
#   '7 - 10 years'],
#  ['Technical Lead - Full Stack Development - .Net/SQL/Sharepoint',
#   'https://www.naukri.com/job-listings-technical-lead-full-stack-development-net-sql-sharepoint-serving-skill-gurgaon-gurugram-12-to-18-years-310123916497',
#   '12 - 18 years'],
#  ['Technical Lead - Full Stack Development',
#   'https://www.naukri.com/job-listings-technical-lead-full-stack-development-serving-skill-noida-5-to-10-years-310123916266',
#   '5 - 10 years'],
#  ['AWS Architect - Full Stack Development',
#   'https://www.naukri.com/job-listings-aws-architect-full-stack-development-serving-skill-bangalore-bengaluru-10-to-14-years-310123916053',
#   '10 - 14 years'],
#  ['Tech Lead - Full Stack Development - Java',
#   'https://www.naukri.com/job-listings-tech-lead-full-stack-development-java-serving-skill-noida-8-to-12-years-310123915858',
#   '8 - 12 years'],
#  ['Software Engineer - Full Stack Development - JavaScript/Node.js',
#   'https://www.naukri.com/job-listings-software-engineer-full-stack-development-javascript-node-js-huquo-consulting-gurgaon-gurugram-3-to-6-years-310123912082',
#   '3 - 6 years'],
#  ['Software Architect - Full Stack Development - PHP / Python',
#   'https://www.naukri.com/job-listings-software-architect-full-stack-development-php-python-imindyourbusiness-bangalore-bengaluru-indiranagar-8-to-12-years-310123908217',
#   '8 - 12 years'],
#  ['Azure with Full Stack Development & Senior Developer',
#   'https://www.naukri.com/job-listings-azure-with-full-stack-development-senior-developer-cliqhr-pune-6-to-9-years-300323904353',
#   '6 - 9 years'],
#  ['Technical Lead - Full Stack Development - Python / JavaScript',
#   'https://www.naukri.com/job-listings-technical-lead-full-stack-development-python-javascript-talent-acceleration-corridor-gurgaon-gurugram-4-to-6-years-281222910409',
#   '4 - 6 years'],
#  ['Head of Technology - Full Stack Development',
#   'https://www.naukri.com/job-listings-head-of-technology-full-stack-development-hyrezy-talent-solution-gurgaon-gurugram-6-to-11-years-281222906712',
#   '6 - 11 years'],
#  ['Technical Lead - Full Stack Development - Node.js / React.js',
#   'https://www.naukri.com/job-listings-technical-lead-full-stack-development-node-js-react-js-hyrezy-talent-solution-chennai-5-to-10-years-281222906616',
#   '5 - 10 years'],
#  ['Senior Software Engineer - Full Stack Development',
#   'https://www.naukri.com/job-listings-senior-software-engineer-full-stack-development-hyrezy-talent-solutions-mumbai-3-to-5-years-280323907373',
#   '3 - 5 years'],
#  ['Senior Software Engineer - Full Stack Development - React.js/TypeScrip',
#   'https://www.naukri.com/job-listings-senior-software-engineer-full-stack-development-react-js-typescrip-hyrezy-talent-solutions-mumbai-3-to-5-years-280323907370',
#   '3 - 5 years'],
#  ['Tech Lead - Full Stack Development',
#   'https://www.naukri.com/job-listings-tech-lead-full-stack-development-hyrezy-talent-solutions-mumbai-8-to-10-years-280323907274',
#   '8 - 10 years'],
#  ['Technical Lead - Full Stack Development - Node.js / React.js',
#   'https://www.naukri.com/job-listings-technical-lead-full-stack-development-node-js-react-js-hyrezy-talent-solutions-chennai-5-to-10-years-280323907153',
#   '5 - 10 years'],
#  ['Tech Lead - Full Stack Development - Entertainment Domain',
#   'https://www.naukri.com/job-listings-tech-lead-full-stack-development-entertainment-domain-hyrezy-talent-solutions-mumbai-8-to-10-years-280323907030',
#   '8 - 10 years'],
#  ['Technical Lead - Full Stack Development - Node.js/React.js',
#   'https://www.naukri.com/job-listings-technical-lead-full-stack-development-node-js-react-js-hyrezy-talent-solutions-chennai-6-to-11-years-280323906829',
#   '6 - 11 years'],
#  ['Software Engineer - Full Stack Development - JavaScript/Node.js',
#   'https://www.naukri.com/job-listings-software-engineer-full-stack-development-javascript-node-js-huquo-consulting-gurgaon-gurugram-3-to-6-years-280323905955',
#   '3 - 6 years'],
#  ['Co-Founder/Chief Technology Officer - Full Stack Development',
#   'https://www.naukri.com/job-listings-co-founder-chief-technology-officer-full-stack-development-benovymed-healthcare-gurgaon-gurugram-delhi-ncr-2-to-7-years-280323904850',
#   '2 - 7 years'],
#  ['Vice President - Full Stack Development',
#   'https://www.naukri.com/job-listings-vice-president-full-stack-development-benovymed-healthcare-delhi-ncr-8-to-12-years-280323904847',
#   '8 - 12 years'],
#  ['Head of Technology - Full Stack Development',
#   'https://www.naukri.com/job-listings-head-of-technology-full-stack-development-hyrezy-talent-solutions-gurgaon-gurugram-6-to-11-years-280323904524',
#   '6 - 11 years'],
#  ['Tech Lead - Full Stack Development - Entertainment Domain',
#   'https://www.naukri.com/job-listings-tech-lead-full-stack-development-entertainment-domain-hyrezy-talent-solutions-mumbai-8-to-10-years-280323904166',
#   '8 - 10 years']]

# %%
a=[]
driver=webdriver.Chrome(executable_path='C:\\BrowserDrivers\\chromedriver.exe')
driver.get('https://www.naukri.com/full-stack-development-jobs?k=full%20stack%20development&nignbevent_src=jobsearchDeskGNB')
salary=driver.find_elements(By.TAG_NAME,'span')
for i in salary:
    if i.get_attribute('class')=="ellipsis fleft ":
        a.append(i.text)
driver.close()
# Out:
# C:\Users\chaitu\AppData\Local\Temp/ipykernel_3660/4278595046.py:2: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver=webdriver.Chrome(executable_path='C:\\BrowserDrivers\\chromedriver.exe')
# C:\Users\chaitu\AppData\Local\Temp/ipykernel_3660/4278595046.py:9: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver=webdriver.Chrome(executable_path='C:\\BrowserDrivers\\chromedriver.exe')

# %%
driver=webdriver.Chrome(executable_path='C:\\BrowserDrivers\\chromedriver.exe')
driver.get('https://www.naukri.com/full-stack-development-jobs-2?k=full%20stack%20development&nignbevent_src=jobsearchDeskGNB')
salary=driver.find_elements(By.TAG_NAME,'span')
for i in salary:
    if i.get_attribute('class')=="ellipsis fleft ":
        a.append(i.text)
driver.close()
# Out:
# C:\Users\chaitu\AppData\Local\Temp/ipykernel_3660/1878557454.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver=webdriver.Chrome(executable_path='C:\\BrowserDrivers\\chromedriver.exe')

# %%
len(a)
# Out:
# 40

# %%
a
# Out:
# ['Not disclosed',
#  'Not disclosed',
#  'Not disclosed',
#  'Not disclosed',
#  'Not disclosed',
#  'Not disclosed',
#  'Not disclosed',
#  'Not disclosed',
#  'Not disclosed',
#  'Not disclosed',
#  'Not disclosed',
#  'Not disclosed',
#  'Not disclosed',
#  'Not disclosed',
#  'Not disclosed',
#  'Not disclosed',
#  'Not disclosed',
#  'Not disclosed',
#  'Not disclosed',
#  'Not disclosed',
#  'Not disclosed',
#  'Not disclosed',
#  'Not disclosed',
#  'Not disclosed',
#  'Not disclosed',
#  'Not disclosed',
#  'Not disclosed',
#  'Not disclosed',
#  'Not disclosed',
#  'Not disclosed',
#  'Not disclosed',
#  'Not disclosed',
#  'Not disclosed',
#  'Not disclosed',
#  'Not disclosed',
#  'Not disclosed',
#  'Not disclosed',
#  'Not disclosed',
#  'Not disclosed',
#  'Not disclosed']

# %%
driver=webdriver.Chrome(executable_path="C:\\BrowserDrivers\\chromedriver.exe")
driver.get("https://www.naukri.com/naukri-jobs?glbl_qcrc=1028")
loc_edu_ks=[]
for i in job_desc[:20]:
    driver=webdriver.Chrome(executable_path='C:\\BrowserDrivers\\chromedriver.exe')
    driver.get(i[1])
    try:
        #location
        loc_xpath=driver.find_element(By.XPATH,"//span[@class='location ']")
        #Education
        edu_elements = driver.find_elements(By.CSS_SELECTOR,'div[class="education"] span')
        edu=[i.text for i in edu_elements]
        #keyskill of click and nonclick
        keyskill_click=driver.find_elements(By.XPATH,"//a[@class='chip clickable']")
        keyskill_nonclick=driver.find_elements(By.CSS_SELECTOR,"a[class='chip non-clickable']")
        ks1=[i.text for i in keyskill_click]
        ks2=[i.text for i in keyskill_nonclick]
        ks=ks1+ks2
        ks="/".join([i.lower() for i in ks])
        loc_edu_ks.append([loc_xpath.text,edu,ks])
    except NoSuchElementException:
        location=driver.find_element(By.CLASS_NAME,"cityLinks")
        edu1=driver.find_element(By.CSS_SELECTOR,"p[class='coPE getUGCourse'] span")
        edu2=driver.find_element(By.CSS_SELECTOR,"p[class='coPE getPGCourse'] span")        
        keys_skills=driver.find_elements(By.CLASS_NAME,'clickable')
        ks=[i.text for i in keys_skills]
        ks="/".join([i.lower() for i in ks])
        loc_edu_ks.append([location.text,[edu1.text,edu2.text],ks])
    driver.close()
# Out:
# C:\Users\chaitu\AppData\Local\Temp/ipykernel_3660/3090822288.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver=webdriver.Chrome(executable_path="C:\\BrowserDrivers\\chromedriver.exe")
# C:\Users\chaitu\AppData\Local\Temp/ipykernel_3660/3090822288.py:5: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver=webdriver.Chrome(executable_path='C:\\BrowserDrivers\\chromedriver.exe')

# %%
len(loc_edu_ks)
# Out:
# 20

# %%
len(a)
# Out:
# 40

# %%
k=0
for i in a:
    job_desc[k].append(i)
    k=k+1

# %%
for i in job_desc[20:]:
    driver=webdriver.Chrome(executable_path='C:\\BrowserDrivers\\chromedriver.exe')
    driver.get(i[1])
    try:
        #location
        loc_xpath=driver.find_element(By.XPATH,"//span[@class='location ']")
        #Education
        edu_elements = driver.find_elements(By.CSS_SELECTOR,'div[class="education"] span')
        edu=[i.text for i in edu_elements]
        #keyskill of click and nonclick
        keyskill_click=driver.find_elements(By.XPATH,"//a[@class='chip clickable']")
        keyskill_nonclick=driver.find_elements(By.CSS_SELECTOR,"a[class='chip non-clickable']")
        ks1=[i.text for i in keyskill_click]
        ks2=[i.text for i in keyskill_nonclick]
        ks=ks1+ks2
        ks="/".join([i.lower() for i in ks])
        loc_edu_ks.append([loc_xpath.text,edu,ks])
    except NoSuchElementException:
        location=driver.find_element(By.CLASS_NAME,"cityLinks")
        edu1=driver.find_element(By.CSS_SELECTOR,"p[class='coPE getUGCourse'] span")
        edu2=driver.find_element(By.CSS_SELECTOR,"p[class='coPE getPGCourse'] span")        
        keys_skills=driver.find_elements(By.CLASS_NAME,'clickable')
        ks=[i.text for i in keys_skills]
        ks="/".join([i.lower() for i in ks])
        loc_edu_ks.append([location.text,[edu1.text,edu2.text],ks])
    driver.close()
# Out:
# C:\Users\chaitu\AppData\Local\Temp/ipykernel_3660/367372912.py:2: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver=webdriver.Chrome(executable_path='C:\\BrowserDrivers\\chromedriver.exe')

# %%
loc_edu_ks
# Out:
# [['Noida, Gurgaon/Gurugram, Delhi / NCR',
#   ['B.Tech/B.E. in Electronics/Telecommunication, Computers',
#    'MBA/PGDM in Any Specialization',
#    'Doctorate Not Required'],
#   'appium/mean stack/software development/devops/mockito/django/dynamo db/robotium/lamp/selenium/aws/full stack/mobile app prototypes/backend development/product software engineering/frontend development'],
#  ['Kolkata, Mumbai, Hyderabad/Secunderabad, Lucknow, Chennai, Ahmedabad, Bangalore/Bengaluru, Delhi / NCR',
#   ['BCA in Any Specialization, B.Tech/B.E. in Any Specialization, B.Sc in Any Specialization',
#    'Any Postgraduate',
#    'Doctorate Not Required'],
#   'rest/mysql/postgresql/sql/microservices/unit testing methodologies/elk stack/messaging systems/estimation techniques/react/angular'],
#  ['Madhya Pradesh',
#   ['B.Tech/B.E. in Computers',
#    'M.Tech in Computers',
#    'Doctorate Not Required'],
#   'api/software architecture/coding/cto/restful api/full stack'],
#  ['Kolkata, Mumbai, Hyderabad/Secunderabad, Chennai, Gurgaon/Gurugram, Delhi / NCR, Bangalore/Bengaluru',
#   ['B.Sc in Any Specialization, BCA in Any Specialization, B.Tech/B.E. in Any Specialization',
#    'Any Postgraduate',
#    'Doctorate Not Required'],
#   'c#/java/postgresql/.net/php/webservices/full stack development'],
#  ['Bangalore/Bengaluru',
#   ['B.Tech/B.E. in Production/Industrial',
#    'M.Tech in Electronics/Telecommunication'],
#   'php/python/java/javascript/json/golang/full stack/aws lambda/rest api/mvc design patterns'],
#  ['Gurgaon/Gurugram',
#   ['B.Sc in Any Specialization, B.Tech/B.E. in Any Specialization, BCA in Any Specialization',
#    'Any Postgraduate',
#    'Doctorate Not Required'],
#   'javascript/node.js/algorithm/data structure/sql/nosql/git/mysql/react.js/aws/elasticache/full stack/dynamodb/nodejs/reactjs'],
#  ['Kolkata, Mumbai, Hyderabad/Secunderabad, Lucknow, Chennai, Ahmedabad, Bangalore/Bengaluru, Delhi / NCR',
#   ['BCA in Any Specialization, B.Tech/B.E. in Any Specialization, B.Sc in Any Specialization',
#    'Any Postgraduate',
#    'Doctorate Not Required'],
#   'css/agile methodologies/html/soap/jenkins/rest/git/docker/javascript/phoenix/elixir/full stack development/babel/npm/gulp/webpack'],
#  ['Chennai',
#   ['B.Sc in Computers, BCA in Computers, B.Tech/B.E. in Computers',
#    'Any Postgraduate',
#    'Doctorate Not Required'],
#   'mongodb/express/postgresql/github/opengl/elixir/firebase/elk/node/electron/react/tailwind'],
#  ['Chennai',
#   ['BCA in Computers, B.Sc in Computers, B.Tech/B.E. in Computers',
#    'M.Tech in Computers, MS/M.Sc(Science) in Computers, MCA in Computers',
#    'Doctorate Not Required'],
#   'software engineering/java/c++/javascript/node.js/mongodb/data structure/python/redux/full stack/flutter'],
#  ['Mohali',
#   ['Any Graduate', 'Any Postgraduate'],
#   'computer science/version control/agile development/cloud/debugging/javascript/mongodb/continuous improvement/software solutions/aws'],
#  ['Hyderabad/Secunderabad',
#   ['BCA in Any Specialization, B.Tech/B.E. in Any Specialization, B.Sc in Any Specialization',
#    'Any Postgraduate',
#    'Doctorate Not Required'],
#   'php/application designing/angularjs/mysql/javascript/node.js/react.js/golang/api integration/restful webservices/full stack'],
#  ['Bangalore/Bengaluru',
#   ['B.Tech/B.E. in Computers',
#    'MS/M.Sc(Science) in Computers, M.Tech in Computers',
#    'Doctorate Not Required'],
#   'java/css/json/html/soap/javascript/javascript/php/python/golang/aws lambda/full stack/rest api design/mvc design patterns/rest api/mvc design patterns/beego'],
#  ['Gurgaon/Gurugram',
#   ['B.Tech/B.E. in Computers, B.Sc in Computers, BCA in Computers',
#    'Any Postgraduate',
#    'Doctorate Not Required'],
#   'python/angularjs/django/javascript/node.js/mongodb/data analytics/startup/full stack/pdlc'],
#  ['Gurgaon/Gurugram',
#   ['B.Tech/B.E. in Computers', 'MCA in Computers', 'Doctorate Not Required'],
#   'java/docker/j2ee/node.js/aws/python/rest api/pl/sql/full stack'],
#  ['Gurgaon/Gurugram',
#   ['B.Sc in Computers, BCA in Computers, B.Tech/B.E. in Computers',
#    'Any Postgraduate',
#    'Doctorate Not Required'],
#   'c#/angularjs/jquery/power bi/ssrs/.net/wcf/sql server/wpf/full stack development'],
#  ['Mumbai, Navi Mumbai',
#   ['B.Tech/B.E. in Any Specialization, B.Sc in Any Specialization, BCA in Computers',
#    'Any Postgraduate',
#    'Doctorate Not Required'],
#   'c#/azure/design patterns/oops/.net/mvc/asp/sql/.net core/webapi/full stack'],
#  ['Noida, Mumbai, Hyderabad/Secunderabad, Pune, Chennai, Bangalore/Bengaluru',
#   ['B.Sc in Any Specialization, BCA in Computers, B.Tech/B.E. in Any Specialization',
#    'Any Postgraduate',
#    'Doctorate Not Required'],
#   'c#/azure/.net/troubleshooting/angular 8/.net core/terraform/full stack'],
#  ['Mumbai',
#   ['BCA in Computers, B.Tech/B.E. in Any Specialization, B.Sc in Any Specialization',
#    'Any Postgraduate',
#    'Doctorate Not Required'],
#   'java/design patterns/ooad/solution design/distributed systems/aws/sql/product roadmap/full stack/solution implementation'],
#  ['Noida, Mumbai, Hyderabad/Secunderabad, Pune, Chennai, Bangalore/Bengaluru',
#   ['BCA in Computers, B.Sc in Any Specialization, B.Tech/B.E. in Any Specialization',
#    'Any Postgraduate',
#    'Doctorate Not Required'],
#   'java/angularjs/spring boot/iot/multithreading/junit/mysql/html5/aws/restful api/eks/cloud services/full stack/css/mockito/sns'],
#  ['Gurgaon/Gurugram',
#   ['BCA in Computers, B.Tech/B.E. in Computers, B.Sc in Computers',
#    'Any Postgraduate',
#    'Doctorate Not Required'],
#   'jquery/power bi/ssrs/.net/mvc/wcf/sql server/react.js/sharepoint/sql/full stack']]

# %%
len(loc_edu_ks)
# Out:
# 40

# %%
loc_edu_ks
# Out:
# [['Noida, Gurgaon/Gurugram, Delhi / NCR',
#   ['B.Tech/B.E. in Electronics/Telecommunication, Computers',
#    'MBA/PGDM in Any Specialization',
#    'Doctorate Not Required'],
#   'appium/mean stack/software development/devops/mockito/django/dynamo db/robotium/lamp/selenium/aws/full stack/mobile app prototypes/backend development/product software engineering/frontend development'],
#  ['Kolkata, Mumbai, Hyderabad/Secunderabad, Lucknow, Chennai, Ahmedabad, Bangalore/Bengaluru, Delhi / NCR',
#   ['BCA in Any Specialization, B.Tech/B.E. in Any Specialization, B.Sc in Any Specialization',
#    'Any Postgraduate',
#    'Doctorate Not Required'],
#   'rest/mysql/postgresql/sql/microservices/unit testing methodologies/elk stack/messaging systems/estimation techniques/react/angular'],
#  ['Madhya Pradesh',
#   ['B.Tech/B.E. in Computers',
#    'M.Tech in Computers',
#    'Doctorate Not Required'],
#   'api/software architecture/coding/cto/restful api/full stack'],
#  ['Kolkata, Mumbai, Hyderabad/Secunderabad, Chennai, Gurgaon/Gurugram, Delhi / NCR, Bangalore/Bengaluru',
#   ['B.Sc in Any Specialization, BCA in Any Specialization, B.Tech/B.E. in Any Specialization',
#    'Any Postgraduate',
#    'Doctorate Not Required'],
#   'c#/java/postgresql/.net/php/webservices/full stack development'],
#  ['Bangalore/Bengaluru',
#   ['B.Tech/B.E. in Production/Industrial',
#    'M.Tech in Electronics/Telecommunication'],
#   'php/python/java/javascript/json/golang/full stack/aws lambda/rest api/mvc design patterns'],
#  ['Gurgaon/Gurugram',
#   ['B.Sc in Any Specialization, B.Tech/B.E. in Any Specialization, BCA in Any Specialization',
#    'Any Postgraduate',
#    'Doctorate Not Required'],
#   'javascript/node.js/algorithm/data structure/sql/nosql/git/mysql/react.js/aws/elasticache/full stack/dynamodb/nodejs/reactjs'],
#  ['Kolkata, Mumbai, Hyderabad/Secunderabad, Lucknow, Chennai, Ahmedabad, Bangalore/Bengaluru, Delhi / NCR',
#   ['BCA in Any Specialization, B.Tech/B.E. in Any Specialization, B.Sc in Any Specialization',
#    'Any Postgraduate',
#    'Doctorate Not Required'],
#   'css/agile methodologies/html/soap/jenkins/rest/git/docker/javascript/phoenix/elixir/full stack development/babel/npm/gulp/webpack'],
#  ['Chennai',
#   ['B.Sc in Computers, BCA in Computers, B.Tech/B.E. in Computers',
#    'Any Postgraduate',
#    'Doctorate Not Required'],
#   'mongodb/express/postgresql/github/opengl/elixir/firebase/elk/node/electron/react/tailwind'],
#  ['Chennai',
#   ['BCA in Computers, B.Sc in Computers, B.Tech/B.E. in Computers',
#    'M.Tech in Computers, MS/M.Sc(Science) in Computers, MCA in Computers',
#    'Doctorate Not Required'],
#   'software engineering/java/c++/javascript/node.js/mongodb/data structure/python/redux/full stack/flutter'],
#  ['Mohali',
#   ['Any Graduate', 'Any Postgraduate'],
#   'computer science/version control/agile development/cloud/debugging/javascript/mongodb/continuous improvement/software solutions/aws'],
#  ['Hyderabad/Secunderabad',
#   ['BCA in Any Specialization, B.Tech/B.E. in Any Specialization, B.Sc in Any Specialization',
#    'Any Postgraduate',
#    'Doctorate Not Required'],
#   'php/application designing/angularjs/mysql/javascript/node.js/react.js/golang/api integration/restful webservices/full stack'],
#  ['Bangalore/Bengaluru',
#   ['B.Tech/B.E. in Computers',
#    'MS/M.Sc(Science) in Computers, M.Tech in Computers',
#    'Doctorate Not Required'],
#   'java/css/json/html/soap/javascript/javascript/php/python/golang/aws lambda/full stack/rest api design/mvc design patterns/rest api/mvc design patterns/beego'],
#  ['Gurgaon/Gurugram',
#   ['B.Tech/B.E. in Computers, B.Sc in Computers, BCA in Computers',
#    'Any Postgraduate',
#    'Doctorate Not Required'],
#   'python/angularjs/django/javascript/node.js/mongodb/data analytics/startup/full stack/pdlc'],
#  ['Gurgaon/Gurugram',
#   ['B.Tech/B.E. in Computers', 'MCA in Computers', 'Doctorate Not Required'],
#   'java/docker/j2ee/node.js/aws/python/rest api/pl/sql/full stack'],
#  ['Gurgaon/Gurugram',
#   ['B.Sc in Computers, BCA in Computers, B.Tech/B.E. in Computers',
#    'Any Postgraduate',
#    'Doctorate Not Required'],
#   'c#/angularjs/jquery/power bi/ssrs/.net/wcf/sql server/wpf/full stack development'],
#  ['Mumbai, Navi Mumbai',
#   ['B.Tech/B.E. in Any Specialization, B.Sc in Any Specialization, BCA in Computers',
#    'Any Postgraduate',
#    'Doctorate Not Required'],
#   'c#/azure/design patterns/oops/.net/mvc/asp/sql/.net core/webapi/full stack'],
#  ['Noida, Mumbai, Hyderabad/Secunderabad, Pune, Chennai, Bangalore/Bengaluru',
#   ['B.Sc in Any Specialization, BCA in Computers, B.Tech/B.E. in Any Specialization',
#    'Any Postgraduate',
#    'Doctorate Not Required'],
#   'c#/azure/.net/troubleshooting/angular 8/.net core/terraform/full stack'],
#  ['Mumbai',
#   ['BCA in Computers, B.Tech/B.E. in Any Specialization, B.Sc in Any Specialization',
#    'Any Postgraduate',
#    'Doctorate Not Required'],
#   'java/design patterns/ooad/solution design/distributed systems/aws/sql/product roadmap/full stack/solution implementation'],
#  ['Noida, Mumbai, Hyderabad/Secunderabad, Pune, Chennai, Bangalore/Bengaluru',
#   ['BCA in Computers, B.Sc in Any Specialization, B.Tech/B.E. in Any Specialization',
#    'Any Postgraduate',
#    'Doctorate Not Required'],
#   'java/angularjs/spring boot/iot/multithreading/junit/mysql/html5/aws/restful api/eks/cloud services/full stack/css/mockito/sns'],
#  ['Gurgaon/Gurugram',
#   ['BCA in Computers, B.Tech/B.E. in Computers, B.Sc in Computers',
#    'Any Postgraduate',
#    'Doctorate Not Required'],
#   'jquery/power bi/ssrs/.net/mvc/wcf/sql server/react.js/sharepoint/sql/full stack'],
#  ['Noida',
#   ['BCA in Computers, B.Sc in Any Specialization, B.Tech/B.E. in Any Specialization',
#    'Any Postgraduate',
#    'Doctorate Not Required'],
#   'angularjs/mvvm/cloud/mongodb/node.js/webservices/typescript/full stack/microservices implementation'],
#  ['Bangalore/Bengaluru',
#   ['BCA in Computers, B.Tech/B.E. in Computers, B.Sc in Computers',
#    'Any Postgraduate',
#    'Doctorate Not Required'],
#   'iam/technical architect/docker/aws/aws lambda/snssqs/restful api/cloudformation/ci/cd/full stack/dynamodb'],
#  ['Noida',
#   ['B.Tech/B.E. in Computers', 'MCA in Computers', 'Doctorate Not Required'],
#   'java/hibernate/ruby on rails/json/mvc/spring/sql/python/microservices architecture/full stack'],
#  ['Gurgaon/Gurugram',
#   ['B.Tech/B.E. in Any Specialization, BCA in Any Specialization, B.Sc in Any Specialization',
#    'Any Postgraduate',
#    'Doctorate Not Required'],
#   'javascript/node.js/react.js/nosql/aws/algorithm/data structure/sql/full stack/dynamodb'],
#  ['Bangalore/Bengaluru, Indiranagar',
#   ['B.Tech/B.E. in Computers',
#    'M.Tech in Computers, MS/M.Sc(Science) in Computers',
#    'Doctorate Not Required'],
#   'java/design patterns/json/css3/javascript/html5/php/mvc/python/full stack development/golang/aws lambda/rest api'],
#  ['Pune',
#   ['B.Tech/B.E. in Any Specialization',
#    'M.Tech in Any Specialization',
#    'Doctorate Not Required'],
#   'architect/azure/html/ css/full stack development'],
#  ['Gurgaon/Gurugram',
#   ['B.Tech/B.E. in Computers, B.Sc in Computers, BCA in Computers',
#    'Any Postgraduate',
#    'Doctorate Not Required'],
#   'python/angularjs/api development/machine learning/linux/ui design/django/javascript/php/mongodb/data analytics/ux design/nodejs'],
#  ['Gurgaon/Gurugram',
#   ['B.Tech/B.E. in Any Specialization, BCA in Any Specialization, B.Sc in Any Specialization',
#    'Any Postgraduate',
#    'Doctorate Not Required'],
#   'amazon ec2/ruby on rails/django/teamcity/node.js/aws/python/full stack development/it automation tools/ci/cd pipeline/restful webservices/full stack'],
#  ['Chennai',
#   ['B.Tech/B.E. in Any Specialization, BCA in Any Specialization, B.Sc in Any Specialization',
#    'Any Postgraduate',
#    'Doctorate Not Required'],
#   'node.js/b2c/nosql/tdd/architecture design/agile development/saas/react.js/sql/b2b saas/cloud scale services/bdd'],
#  ['Mumbai',
#   ['B.Sc in Computers', 'Any Postgraduate', 'Doctorate Not Required'],
#   'distribution system/ux/software engineering/javascript/go/react.js/python/figma/typescript/redux'],
#  ['Mumbai',
#   ['B.Sc in Computers', 'Any Postgraduate', 'Doctorate Not Required'],
#   'distribution system/ux/software engineering/javascript/go/react.js/python/figma/typescript/redux'],
#  ['Mumbai',
#   ['BCA in Any Specialization, B.Sc in Any Specialization, B.Tech/B.E. in Any Specialization',
#    'Any Postgraduate',
#    'Doctorate Not Required'],
#   'javascript/css/html5/node.js/jira/vue/react native/react/angular'],
#  ['Chennai',
#   ['B.Tech/B.E. in Any Specialization, BCA in Any Specialization, B.Sc in Any Specialization',
#    'Any Postgraduate',
#    'Doctorate Not Required'],
#   'node.js/b2c/nosql/tdd/architecture design/agile development/saas/react.js/sql/b2b saas/cloud scale services/bdd'],
#  ['Mumbai',
#   ['B.Tech/B.E. in Any Specialization, B.Sc in Any Specialization, BCA in Any Specialization',
#    'Any Postgraduate',
#    'Doctorate Not Required'],
#   'javascript/css/html5/php/node.js/react js/react native/angular'],
#  ['Chennai',
#   ['B.Sc in Any Specialization, B.Tech/B.E. in Any Specialization, BCA in Any Specialization',
#    'Any Postgraduate',
#    'Doctorate Not Required'],
#   'nosql/tdd/node.js/application lifecycle management/react.js/agile development/sql/blockchain'],
#  ['Gurgaon/Gurugram',
#   ['B.Tech/B.E. in Any Specialization, B.Sc in Any Specialization, BCA in Any Specialization',
#    'Any Postgraduate',
#    'Doctorate Not Required'],
#   'javascript/node.js/react.js/nosql/aws/algorithm/data structure/sql/full stack/dynamodb'],
#  ['Gurgaon/Gurugram, Delhi / NCR',
#   ['B.Tech/B.E. in Electronics/Telecommunication, Computers',
#    'Any Postgraduate',
#    'Doctorate Not Required'],
#   'javascript/mean/java/css/html/django/dynamo db/mysql/php/.net/mongodb/lamp/oracle/aws/ruby/python/amber/react/angular js/nosql db'],
#  ['Delhi / NCR',
#   ['B.Tech/B.E. in Electronics/Telecommunication, Computers',
#    'Any Postgraduate',
#    'Doctorate Not Required'],
#   'java/project management/engineering management/mysql/mongodb/node.js/aws/solution architect/python/full stack development/full stack/saas applications'],
#  ['Gurgaon/Gurugram',
#   ['B.Tech/B.E. in Any Specialization, B.Sc in Any Specialization, BCA in Any Specialization',
#    'Any Postgraduate',
#    'Doctorate Not Required'],
#   'amazon ec2/software development lifecycle/postgresql/redis/node.js/sdlc/ruby on rails/tdd/django/teamcity/mysql/mongodb/aws/python/full stack development/material design/ci/cd pipeline/restful webservices/it automation tools/aws dynamodb/microservices development'],
#  ['Mumbai',
#   ['B.Tech/B.E. in Any Specialization, BCA in Any Specialization, B.Sc in Any Specialization',
#    'Any Postgraduate',
#    'Doctorate Not Required'],
#   'ios/angularjs/node.js/jira/zoho/agile development/php/react.js/full stack/scrum project methodologies/project management tools/vue.js/mobile app architecture/react native/full stack javascript']]

# %%
k=0
for i in loc_edu_ks:
    job_desc[k].append(i[0])
    job_desc[k].append(i[1])
    job_desc[k].append(i[2])
    k=k+1

# %%
import pandas as pd
df=pd.DataFrame(job_desc,columns=["Name","Link","Work Experience","Salary","Location","Education","KeySkills"])
df
# Out:
#                                                  Name  \
# 0   Chief Technology Officer/Vice President - Full...
# 1           Engineering Lead - Full Stack Development
# 2   Tech Lead/CTO - Full Stack Development - Web &...
# 3           Engineering Lead - Full Stack Development
# 4         Software Architect - Full Stack Development
# 5   Software Engineer- Full Stack Development- Jav...
# 6   Senior Software Engineer - Full Stack Development
# 7                  Team Lead - Full Stack Development
# 8          Software Engineer - Full Stack Development
# 9                              Full Stack Development
# 10            Technical Lead - Full Stack Development
# 11  Software Architect - Full Stack Development - ...
# 12  Technical Lead - Full Stack Development - Pyth...
# 13  Senior Technical Consultant - Full Stack Devel...
# 14            Technical Lead - Full Stack Development
# 15  Senior Software Engineer - Full Stack Development
# 16   Technical Lead I - Full Stack Development - .Net
# 17  Lead/Principal Software Engineer - Full Stack ...
# 18  Technical Lead II - Full Stack Development - J...
# 19  Technical Lead - Full Stack Development - .Net...
# 20            Technical Lead - Full Stack Development
# 21             AWS Architect - Full Stack Development
# 22          Tech Lead - Full Stack Development - Java
# 23  Software Engineer - Full Stack Development - J...
# 24  Software Architect - Full Stack Development - ...
# 25  Azure with Full Stack Development & Senior Dev...
# 26  Technical Lead - Full Stack Development - Pyth...
# 27        Head of Technology - Full Stack Development
# 28  Technical Lead - Full Stack Development - Node...
# 29  Senior Software Engineer - Full Stack Development
# 30  Senior Software Engineer - Full Stack Developm...
# 31                 Tech Lead - Full Stack Development
# 32  Technical Lead - Full Stack Development - Node...
# 33  Tech Lead - Full Stack Development - Entertain...
# 34  Technical Lead - Full Stack Development - Node...
# 35  Software Engineer - Full Stack Development - J...
# 36  Co-Founder/Chief Technology Officer - Full Sta...
# 37            Vice President - Full Stack Development
# 38        Head of Technology - Full Stack Development
# 39  Tech Lead - Full Stack Development - Entertain...
#
#                                                  Link Work Experience  \
# 0   https://www.naukri.com/job-listings-chief-tech...     2 - 7 years
# 1   https://www.naukri.com/job-listings-engineerin...   10 - 12 years
# 2   https://www.naukri.com/job-listings-tech-lead-...     5 - 7 years
# 3   https://www.naukri.com/job-listings-engineerin...   10 - 12 years
# 4   https://www.naukri.com/job-listings-software-a...    7 - 10 years
# 5   https://www.naukri.com/job-listings-software-e...     3 - 6 years
# 6   https://www.naukri.com/job-listings-senior-sof...     5 - 8 years
# 7   https://www.naukri.com/job-listings-team-lead-...     5 - 8 years
# 8   https://www.naukri.com/job-listings-software-e...     2 - 4 years
# 9   https://www.naukri.com/job-listings-full-stack...     1 - 4 years
# 10  https://www.naukri.com/job-listings-technical-...    8 - 12 years
# 11  https://www.naukri.com/job-listings-software-a...    8 - 12 years
# 12  https://www.naukri.com/job-listings-technical-...     4 - 8 years
# 13  https://www.naukri.com/job-listings-senior-tec...   12 - 15 years
# 14  https://www.naukri.com/job-listings-technical-...   12 - 18 years
# 15  https://www.naukri.com/job-listings-senior-sof...     3 - 5 years
# 16  https://www.naukri.com/job-listings-technical-...    7 - 10 years
# 17  https://www.naukri.com/job-listings-lead-princ...    6 - 11 years
# 18  https://www.naukri.com/job-listings-technical-...    7 - 10 years
# 19  https://www.naukri.com/job-listings-technical-...   12 - 18 years
# 20  https://www.naukri.com/job-listings-technical-...    5 - 10 years
# 21  https://www.naukri.com/job-listings-aws-archit...   10 - 14 years
# 22  https://www.naukri.com/job-listings-tech-lead-...    8 - 12 years
# 23  https://www.naukri.com/job-listings-software-e...     3 - 6 years
# 24  https://www.naukri.com/job-listings-software-a...    8 - 12 years
# 25  https://www.naukri.com/job-listings-azure-with...     6 - 9 years
# 26  https://www.naukri.com/job-listings-technical-...     4 - 6 years
# 27  https://www.naukri.com/job-listings-head-of-te...    6 - 11 years
# 28  https://www.naukri.com/job-listings-technical-...    5 - 10 years
# 29  https://www.naukri.com/job-listings-senior-sof...     3 - 5 years
# 30  https://www.naukri.com/job-listings-senior-sof...     3 - 5 years
# 31  https://www.naukri.com/job-listings-tech-lead-...    8 - 10 years
# 32  https://www.naukri.com/job-listings-technical-...    5 - 10 years
# 33  https://www.naukri.com/job-listings-tech-lead-...    8 - 10 years
# 34  https://www.naukri.com/job-listings-technical-...    6 - 11 years
# 35  https://www.naukri.com/job-listings-software-e...     3 - 6 years
# 36  https://www.naukri.com/job-listings-co-founder...     2 - 7 years
# 37  https://www.naukri.com/job-listings-vice-presi...    8 - 12 years
# 38  https://www.naukri.com/job-listings-head-of-te...    6 - 11 years
# 39  https://www.naukri.com/job-listings-tech-lead-...    8 - 10 years
#
#            Salary                                           Location  \
# 0   Not disclosed               Noida, Gurgaon/Gurugram, Delhi / NCR
# 1   Not disclosed  Kolkata, Mumbai, Hyderabad/Secunderabad, Luckn...
# 2   Not disclosed                                     Madhya Pradesh
# 3   Not disclosed  Kolkata, Mumbai, Hyderabad/Secunderabad, Chenn...
# 4   Not disclosed                                Bangalore/Bengaluru
# 5   Not disclosed                                   Gurgaon/Gurugram
# 6   Not disclosed  Kolkata, Mumbai, Hyderabad/Secunderabad, Luckn...
# 7   Not disclosed                                            Chennai
# 8   Not disclosed                                            Chennai
# 9   Not disclosed                                             Mohali
# 10  Not disclosed                             Hyderabad/Secunderabad
# 11  Not disclosed                                Bangalore/Bengaluru
# 12  Not disclosed                                   Gurgaon/Gurugram
# 13  Not disclosed                                   Gurgaon/Gurugram
# 14  Not disclosed                                   Gurgaon/Gurugram
# 15  Not disclosed                                Mumbai, Navi Mumbai
# 16  Not disclosed  Noida, Mumbai, Hyderabad/Secunderabad, Pune, C...
# 17  Not disclosed                                             Mumbai
# 18  Not disclosed  Noida, Mumbai, Hyderabad/Secunderabad, Pune, C...
# 19  Not disclosed                                   Gurgaon/Gurugram
# 20  Not disclosed                                              Noida
# 21  Not disclosed                                Bangalore/Bengaluru
# 22  Not disclosed                                              Noida
# 23  Not disclosed                                   Gurgaon/Gurugram
# 24  Not disclosed                   Bangalore/Bengaluru, Indiranagar
# 25  Not disclosed                                               Pune
# 26  Not disclosed                                   Gurgaon/Gurugram
# 27  Not disclosed                                   Gurgaon/Gurugram
# 28  Not disclosed                                            Chennai
# 29  Not disclosed                                             Mumbai
# 30  Not disclosed                                             Mumbai
# 31  Not disclosed                                             Mumbai
# 32  Not disclosed                                            Chennai
# 33  Not disclosed                                             Mumbai
# 34  Not disclosed                                            Chennai
# 35  Not disclosed                                   Gurgaon/Gurugram
# 36  Not disclosed                      Gurgaon/Gurugram, Delhi / NCR
# 37  Not disclosed                                        Delhi / NCR
# 38  Not disclosed                                   Gurgaon/Gurugram
# 39  Not disclosed                                             Mumbai
#
#                                             Education  \
# 0   [B.Tech/B.E. in Electronics/Telecommunication,...
# 1   [BCA in Any Specialization, B.Tech/B.E. in Any...
# 2   [B.Tech/B.E. in Computers, M.Tech in Computers...
# 3   [B.Sc in Any Specialization, BCA in Any Specia...
# 4   [B.Tech/B.E. in Production/Industrial, M.Tech ...
# 5   [B.Sc in Any Specialization, B.Tech/B.E. in An...
# 6   [BCA in Any Specialization, B.Tech/B.E. in Any...
# 7   [B.Sc in Computers, BCA in Computers, B.Tech/B...
# 8   [BCA in Computers, B.Sc in Computers, B.Tech/B...
# 9                    [Any Graduate, Any Postgraduate]
# 10  [BCA in Any Specialization, B.Tech/B.E. in Any...
# 11  [B.Tech/B.E. in Computers, MS/M.Sc(Science) in...
# 12  [B.Tech/B.E. in Computers, B.Sc in Computers, ...
# 13  [B.Tech/B.E. in Computers, MCA in Computers, D...
# 14  [B.Sc in Computers, BCA in Computers, B.Tech/B...
# 15  [B.Tech/B.E. in Any Specialization, B.Sc in An...
# 16  [B.Sc in Any Specialization, BCA in Computers,...
# 17  [BCA in Computers, B.Tech/B.E. in Any Speciali...
# 18  [BCA in Computers, B.Sc in Any Specialization,...
# 19  [BCA in Computers, B.Tech/B.E. in Computers, B...
# 20  [BCA in Computers, B.Sc in Any Specialization,...
# 21  [BCA in Computers, B.Tech/B.E. in Computers, B...
# 22  [B.Tech/B.E. in Computers, MCA in Computers, D...
# 23  [B.Tech/B.E. in Any Specialization, BCA in Any...
# 24  [B.Tech/B.E. in Computers, M.Tech in Computers...
# 25  [B.Tech/B.E. in Any Specialization, M.Tech in ...
# 26  [B.Tech/B.E. in Computers, B.Sc in Computers, ...
# 27  [B.Tech/B.E. in Any Specialization, BCA in Any...
# 28  [B.Tech/B.E. in Any Specialization, BCA in Any...
# 29  [B.Sc in Computers, Any Postgraduate, Doctorat...
# 30  [B.Sc in Computers, Any Postgraduate, Doctorat...
# 31  [BCA in Any Specialization, B.Sc in Any Specia...
# 32  [B.Tech/B.E. in Any Specialization, BCA in Any...
# 33  [B.Tech/B.E. in Any Specialization, B.Sc in An...
# 34  [B.Sc in Any Specialization, B.Tech/B.E. in An...
# 35  [B.Tech/B.E. in Any Specialization, B.Sc in An...
# 36  [B.Tech/B.E. in Electronics/Telecommunication,...
# 37  [B.Tech/B.E. in Electronics/Telecommunication,...
# 38  [B.Tech/B.E. in Any Specialization, B.Sc in An...
# 39  [B.Tech/B.E. in Any Specialization, BCA in Any...
#
#                                             KeySkills
# 0   appium/mean stack/software development/devops/...
# 1   rest/mysql/postgresql/sql/microservices/unit t...
# 2   api/software architecture/coding/cto/restful a...
# 3   c#/java/postgresql/.net/php/webservices/full s...
# 4   php/python/java/javascript/json/golang/full st...
# 5   javascript/node.js/algorithm/data structure/sq...
# 6   css/agile methodologies/html/soap/jenkins/rest...
# 7   mongodb/express/postgresql/github/opengl/elixi...
# 8   software engineering/java/c++/javascript/node....
# 9   computer science/version control/agile develop...
# 10  php/application designing/angularjs/mysql/java...
# 11  java/css/json/html/soap/javascript/javascript/...
# 12  python/angularjs/django/javascript/node.js/mon...
# 13  java/docker/j2ee/node.js/aws/python/rest api/p...
# 14  c#/angularjs/jquery/power bi/ssrs/.net/wcf/sql...
# 15  c#/azure/design patterns/oops/.net/mvc/asp/sql...
# 16  c#/azure/.net/troubleshooting/angular 8/.net c...
# 17  java/design patterns/ooad/solution design/dist...
# 18  java/angularjs/spring boot/iot/multithreading/...
# 19  jquery/power bi/ssrs/.net/mvc/wcf/sql server/r...
# 20  angularjs/mvvm/cloud/mongodb/node.js/webservic...
# 21  iam/technical architect/docker/aws/aws lambda/...
# 22  java/hibernate/ruby on rails/json/mvc/spring/s...
# 23  javascript/node.js/react.js/nosql/aws/algorith...
# 24  java/design patterns/json/css3/javascript/html...
# 25   architect/azure/html/ css/full stack development
# 26  python/angularjs/api development/machine learn...
# 27  amazon ec2/ruby on rails/django/teamcity/node....
# 28  node.js/b2c/nosql/tdd/architecture design/agil...
# 29  distribution system/ux/software engineering/ja...
# 30  distribution system/ux/software engineering/ja...
# 31  javascript/css/html5/node.js/jira/vue/react na...
# 32  node.js/b2c/nosql/tdd/architecture design/agil...
# 33  javascript/css/html5/php/node.js/react js/reac...
# 34  nosql/tdd/node.js/application lifecycle manage...
# 35  javascript/node.js/react.js/nosql/aws/algorith...
# 36  javascript/mean/java/css/html/django/dynamo db...
# 37  java/project management/engineering management...
# 38  amazon ec2/software development lifecycle/post...
# 39  ios/angularjs/node.js/jira/zoho/agile developm...

# %%
# min years
min_years=[]
max_years=[]
for i in df['Work Experience']:
    b=i.split()
    b=[i for i in b if i.isdigit()]
    min_years.append(b[0])
    max_years.append(b[1])

# %%
df["min_years"]=min_years
df['max_years']=max_years

# %%
df
# Out:
#                                                  Name  \
# 0   Chief Technology Officer/Vice President - Full...
# 1           Engineering Lead - Full Stack Development
# 2   Tech Lead/CTO - Full Stack Development - Web &...
# 3           Engineering Lead - Full Stack Development
# 4         Software Architect - Full Stack Development
# 5   Software Engineer- Full Stack Development- Jav...
# 6   Senior Software Engineer - Full Stack Development
# 7                  Team Lead - Full Stack Development
# 8          Software Engineer - Full Stack Development
# 9                              Full Stack Development
# 10            Technical Lead - Full Stack Development
# 11  Software Architect - Full Stack Development - ...
# 12  Technical Lead - Full Stack Development - Pyth...
# 13  Senior Technical Consultant - Full Stack Devel...
# 14            Technical Lead - Full Stack Development
# 15  Senior Software Engineer - Full Stack Development
# 16   Technical Lead I - Full Stack Development - .Net
# 17  Lead/Principal Software Engineer - Full Stack ...
# 18  Technical Lead II - Full Stack Development - J...
# 19  Technical Lead - Full Stack Development - .Net...
# 20            Technical Lead - Full Stack Development
# 21             AWS Architect - Full Stack Development
# 22          Tech Lead - Full Stack Development - Java
# 23  Software Engineer - Full Stack Development - J...
# 24  Software Architect - Full Stack Development - ...
# 25  Azure with Full Stack Development & Senior Dev...
# 26  Technical Lead - Full Stack Development - Pyth...
# 27        Head of Technology - Full Stack Development
# 28  Technical Lead - Full Stack Development - Node...
# 29  Senior Software Engineer - Full Stack Development
# 30  Senior Software Engineer - Full Stack Developm...
# 31                 Tech Lead - Full Stack Development
# 32  Technical Lead - Full Stack Development - Node...
# 33  Tech Lead - Full Stack Development - Entertain...
# 34  Technical Lead - Full Stack Development - Node...
# 35  Software Engineer - Full Stack Development - J...
# 36  Co-Founder/Chief Technology Officer - Full Sta...
# 37            Vice President - Full Stack Development
# 38        Head of Technology - Full Stack Development
# 39  Tech Lead - Full Stack Development - Entertain...
#
#                                                  Link Work Experience  \
# 0   https://www.naukri.com/job-listings-chief-tech...     2 - 7 years
# 1   https://www.naukri.com/job-listings-engineerin...   10 - 12 years
# 2   https://www.naukri.com/job-listings-tech-lead-...     5 - 7 years
# 3   https://www.naukri.com/job-listings-engineerin...   10 - 12 years
# 4   https://www.naukri.com/job-listings-software-a...    7 - 10 years
# 5   https://www.naukri.com/job-listings-software-e...     3 - 6 years
# 6   https://www.naukri.com/job-listings-senior-sof...     5 - 8 years
# 7   https://www.naukri.com/job-listings-team-lead-...     5 - 8 years
# 8   https://www.naukri.com/job-listings-software-e...     2 - 4 years
# 9   https://www.naukri.com/job-listings-full-stack...     1 - 4 years
# 10  https://www.naukri.com/job-listings-technical-...    8 - 12 years
# 11  https://www.naukri.com/job-listings-software-a...    8 - 12 years
# 12  https://www.naukri.com/job-listings-technical-...     4 - 8 years
# 13  https://www.naukri.com/job-listings-senior-tec...   12 - 15 years
# 14  https://www.naukri.com/job-listings-technical-...   12 - 18 years
# 15  https://www.naukri.com/job-listings-senior-sof...     3 - 5 years
# 16  https://www.naukri.com/job-listings-technical-...    7 - 10 years
# 17  https://www.naukri.com/job-listings-lead-princ...    6 - 11 years
# 18  https://www.naukri.com/job-listings-technical-...    7 - 10 years
# 19  https://www.naukri.com/job-listings-technical-...   12 - 18 years
# 20  https://www.naukri.com/job-listings-technical-...    5 - 10 years
# 21  https://www.naukri.com/job-listings-aws-archit...   10 - 14 years
# 22  https://www.naukri.com/job-listings-tech-lead-...    8 - 12 years
# 23  https://www.naukri.com/job-listings-software-e...     3 - 6 years
# 24  https://www.naukri.com/job-listings-software-a...    8 - 12 years
# 25  https://www.naukri.com/job-listings-azure-with...     6 - 9 years
# 26  https://www.naukri.com/job-listings-technical-...     4 - 6 years
# 27  https://www.naukri.com/job-listings-head-of-te...    6 - 11 years
# 28  https://www.naukri.com/job-listings-technical-...    5 - 10 years
# 29  https://www.naukri.com/job-listings-senior-sof...     3 - 5 years
# 30  https://www.naukri.com/job-listings-senior-sof...     3 - 5 years
# 31  https://www.naukri.com/job-listings-tech-lead-...    8 - 10 years
# 32  https://www.naukri.com/job-listings-technical-...    5 - 10 years
# 33  https://www.naukri.com/job-listings-tech-lead-...    8 - 10 years
# 34  https://www.naukri.com/job-listings-technical-...    6 - 11 years
# 35  https://www.naukri.com/job-listings-software-e...     3 - 6 years
# 36  https://www.naukri.com/job-listings-co-founder...     2 - 7 years
# 37  https://www.naukri.com/job-listings-vice-presi...    8 - 12 years
# 38  https://www.naukri.com/job-listings-head-of-te...    6 - 11 years
# 39  https://www.naukri.com/job-listings-tech-lead-...    8 - 10 years
#
#            Salary                                           Location  \
# 0   Not disclosed               Noida, Gurgaon/Gurugram, Delhi / NCR
# 1   Not disclosed  Kolkata, Mumbai, Hyderabad/Secunderabad, Luckn...
# 2   Not disclosed                                     Madhya Pradesh
# 3   Not disclosed  Kolkata, Mumbai, Hyderabad/Secunderabad, Chenn...
# 4   Not disclosed                                Bangalore/Bengaluru
# 5   Not disclosed                                   Gurgaon/Gurugram
# 6   Not disclosed  Kolkata, Mumbai, Hyderabad/Secunderabad, Luckn...
# 7   Not disclosed                                            Chennai
# 8   Not disclosed                                            Chennai
# 9   Not disclosed                                             Mohali
# 10  Not disclosed                             Hyderabad/Secunderabad
# 11  Not disclosed                                Bangalore/Bengaluru
# 12  Not disclosed                                   Gurgaon/Gurugram
# 13  Not disclosed                                   Gurgaon/Gurugram
# 14  Not disclosed                                   Gurgaon/Gurugram
# 15  Not disclosed                                Mumbai, Navi Mumbai
# 16  Not disclosed  Noida, Mumbai, Hyderabad/Secunderabad, Pune, C...
# 17  Not disclosed                                             Mumbai
# 18  Not disclosed  Noida, Mumbai, Hyderabad/Secunderabad, Pune, C...
# 19  Not disclosed                                   Gurgaon/Gurugram
# 20  Not disclosed                                              Noida
# 21  Not disclosed                                Bangalore/Bengaluru
# 22  Not disclosed                                              Noida
# 23  Not disclosed                                   Gurgaon/Gurugram
# 24  Not disclosed                   Bangalore/Bengaluru, Indiranagar
# 25  Not disclosed                                               Pune
# 26  Not disclosed                                   Gurgaon/Gurugram
# 27  Not disclosed                                   Gurgaon/Gurugram
# 28  Not disclosed                                            Chennai
# 29  Not disclosed                                             Mumbai
# 30  Not disclosed                                             Mumbai
# 31  Not disclosed                                             Mumbai
# 32  Not disclosed                                            Chennai
# 33  Not disclosed                                             Mumbai
# 34  Not disclosed                                            Chennai
# 35  Not disclosed                                   Gurgaon/Gurugram
# 36  Not disclosed                      Gurgaon/Gurugram, Delhi / NCR
# 37  Not disclosed                                        Delhi / NCR
# 38  Not disclosed                                   Gurgaon/Gurugram
# 39  Not disclosed                                             Mumbai
#
#                                             Education  \
# 0   [B.Tech/B.E. in Electronics/Telecommunication,...
# 1   [BCA in Any Specialization, B.Tech/B.E. in Any...
# 2   [B.Tech/B.E. in Computers, M.Tech in Computers...
# 3   [B.Sc in Any Specialization, BCA in Any Specia...
# 4   [B.Tech/B.E. in Production/Industrial, M.Tech ...
# 5   [B.Sc in Any Specialization, B.Tech/B.E. in An...
# 6   [BCA in Any Specialization, B.Tech/B.E. in Any...
# 7   [B.Sc in Computers, BCA in Computers, B.Tech/B...
# 8   [BCA in Computers, B.Sc in Computers, B.Tech/B...
# 9                    [Any Graduate, Any Postgraduate]
# 10  [BCA in Any Specialization, B.Tech/B.E. in Any...
# 11  [B.Tech/B.E. in Computers, MS/M.Sc(Science) in...
# 12  [B.Tech/B.E. in Computers, B.Sc in Computers, ...
# 13  [B.Tech/B.E. in Computers, MCA in Computers, D...
# 14  [B.Sc in Computers, BCA in Computers, B.Tech/B...
# 15  [B.Tech/B.E. in Any Specialization, B.Sc in An...
# 16  [B.Sc in Any Specialization, BCA in Computers,...
# 17  [BCA in Computers, B.Tech/B.E. in Any Speciali...
# 18  [BCA in Computers, B.Sc in Any Specialization,...
# 19  [BCA in Computers, B.Tech/B.E. in Computers, B...
# 20  [BCA in Computers, B.Sc in Any Specialization,...
# 21  [BCA in Computers, B.Tech/B.E. in Computers, B...
# 22  [B.Tech/B.E. in Computers, MCA in Computers, D...
# 23  [B.Tech/B.E. in Any Specialization, BCA in Any...
# 24  [B.Tech/B.E. in Computers, M.Tech in Computers...
# 25  [B.Tech/B.E. in Any Specialization, M.Tech in ...
# 26  [B.Tech/B.E. in Computers, B.Sc in Computers, ...
# 27  [B.Tech/B.E. in Any Specialization, BCA in Any...
# 28  [B.Tech/B.E. in Any Specialization, BCA in Any...
# 29  [B.Sc in Computers, Any Postgraduate, Doctorat...
# 30  [B.Sc in Computers, Any Postgraduate, Doctorat...
# 31  [BCA in Any Specialization, B.Sc in Any Specia...
# 32  [B.Tech/B.E. in Any Specialization, BCA in Any...
# 33  [B.Tech/B.E. in Any Specialization, B.Sc in An...
# 34  [B.Sc in Any Specialization, B.Tech/B.E. in An...
# 35  [B.Tech/B.E. in Any Specialization, B.Sc in An...
# 36  [B.Tech/B.E. in Electronics/Telecommunication,...
# 37  [B.Tech/B.E. in Electronics/Telecommunication,...
# 38  [B.Tech/B.E. in Any Specialization, B.Sc in An...
# 39  [B.Tech/B.E. in Any Specialization, BCA in Any...
#
#                                             KeySkills min_years max_years
# 0   appium/mean stack/software development/devops/...         2         7
# 1   rest/mysql/postgresql/sql/microservices/unit t...        10        12
# 2   api/software architecture/coding/cto/restful a...         5         7
# 3   c#/java/postgresql/.net/php/webservices/full s...        10        12
# 4   php/python/java/javascript/json/golang/full st...         7        10
# 5   javascript/node.js/algorithm/data structure/sq...         3         6
# 6   css/agile methodologies/html/soap/jenkins/rest...         5         8
# 7   mongodb/express/postgresql/github/opengl/elixi...         5         8
# 8   software engineering/java/c++/javascript/node....         2         4
# 9   computer science/version control/agile develop...         1         4
# 10  php/application designing/angularjs/mysql/java...         8        12
# 11  java/css/json/html/soap/javascript/javascript/...         8        12
# 12  python/angularjs/django/javascript/node.js/mon...         4         8
# 13  java/docker/j2ee/node.js/aws/python/rest api/p...        12        15
# 14  c#/angularjs/jquery/power bi/ssrs/.net/wcf/sql...        12        18
# 15  c#/azure/design patterns/oops/.net/mvc/asp/sql...         3         5
# 16  c#/azure/.net/troubleshooting/angular 8/.net c...         7        10
# 17  java/design patterns/ooad/solution design/dist...         6        11
# 18  java/angularjs/spring boot/iot/multithreading/...         7        10
# 19  jquery/power bi/ssrs/.net/mvc/wcf/sql server/r...        12        18
# 20  angularjs/mvvm/cloud/mongodb/node.js/webservic...         5        10
# 21  iam/technical architect/docker/aws/aws lambda/...        10        14
# 22  java/hibernate/ruby on rails/json/mvc/spring/s...         8        12
# 23  javascript/node.js/react.js/nosql/aws/algorith...         3         6
# 24  java/design patterns/json/css3/javascript/html...         8        12
# 25   architect/azure/html/ css/full stack development         6         9
# 26  python/angularjs/api development/machine learn...         4         6
# 27  amazon ec2/ruby on rails/django/teamcity/node....         6        11
# 28  node.js/b2c/nosql/tdd/architecture design/agil...         5        10
# 29  distribution system/ux/software engineering/ja...         3         5
# 30  distribution system/ux/software engineering/ja...         3         5
# 31  javascript/css/html5/node.js/jira/vue/react na...         8        10
# 32  node.js/b2c/nosql/tdd/architecture design/agil...         5        10
# 33  javascript/css/html5/php/node.js/react js/reac...         8        10
# 34  nosql/tdd/node.js/application lifecycle manage...         6        11
# 35  javascript/node.js/react.js/nosql/aws/algorith...         3         6
# 36  javascript/mean/java/css/html/django/dynamo db...         2         7
# 37  java/project management/engineering management...         8        12
# 38  amazon ec2/software development lifecycle/post...         6        11
# 39  ios/angularjs/node.js/jira/zoho/agile developm...         8        10

# %%
undergraduate=[]
for i in df["Education"]:
    if i[0]!="Any Graduate":
        a=[j for j in i[0].split() if j[0]=="B"]
        a="/".join([i for i in a])
        undergraduate.append(a)
#         a=''.join([i.lower() for i in a if i!='.'])

    else:
        undergraduate.append(i[0])
print(undergraduate)
print(len(undergraduate))
# Out:
# ['B.Tech/B.E.', 'BCA/B.Tech/B.E./B.Sc', 'B.Tech/B.E.', 'B.Sc/BCA/B.Tech/B.E.', 'B.Tech/B.E.', 'B.Sc/B.Tech/B.E./BCA', 'BCA/B.Tech/B.E./B.Sc', 'B.Sc/BCA/B.Tech/B.E.', 'BCA/B.Sc/B.Tech/B.E.', 'Any Graduate', 'BCA/B.Tech/B.E./B.Sc', 'B.Tech/B.E.', 'B.Tech/B.E./B.Sc/BCA', 'B.Tech/B.E.', 'B.Sc/BCA/B.Tech/B.E.', 'B.Tech/B.E./B.Sc/BCA', 'B.Sc/BCA/B.Tech/B.E.', 'BCA/B.Tech/B.E./B.Sc', 'BCA/B.Sc/B.Tech/B.E.', 'BCA/B.Tech/B.E./B.Sc', 'BCA/B.Sc/B.Tech/B.E.', 'BCA/B.Tech/B.E./B.Sc', 'B.Tech/B.E.', 'B.Tech/B.E./BCA/B.Sc', 'B.Tech/B.E.', 'B.Tech/B.E.', 'B.Tech/B.E./B.Sc/BCA', 'B.Tech/B.E./BCA/B.Sc', 'B.Tech/B.E./BCA/B.Sc', 'B.Sc', 'B.Sc', 'BCA/B.Sc/B.Tech/B.E.', 'B.Tech/B.E./BCA/B.Sc', 'B.Tech/B.E./B.Sc/BCA', 'B.Sc/B.Tech/B.E./BCA', 'B.Tech/B.E./B.Sc/BCA', 'B.Tech/B.E.', 'B.Tech/B.E.', 'B.Tech/B.E./B.Sc/BCA', 'B.Tech/B.E./BCA/B.Sc']
# 40

# %%
postgraduate=[]
for i in df["Education"]:
    if len(i)>1:
        if i[1]!="Any Postgraduate":
            a=[j for j in i[1].split() if j[0]=="M"]
            a="/".join([i for i in a])
            postgraduate.append(a)
        else:
            postgraduate.append(i[1])
            
    else:
        postgraduate.append("Not Disclosed")
print(postgraduate)
print(len(postgraduate))
# Out:
# ['MBA/PGDM', 'Any Postgraduate', 'M.Tech', 'Any Postgraduate', 'M.Tech', 'Any Postgraduate', 'Any Postgraduate', 'Any Postgraduate', 'M.Tech/MS/M.Sc(Science)/MCA', 'Any Postgraduate', 'Any Postgraduate', 'MS/M.Sc(Science)/M.Tech', 'Any Postgraduate', 'MCA', 'Any Postgraduate', 'Any Postgraduate', 'Any Postgraduate', 'Any Postgraduate', 'Any Postgraduate', 'Any Postgraduate', 'Any Postgraduate', 'Any Postgraduate', 'MCA', 'Any Postgraduate', 'M.Tech/MS/M.Sc(Science)', 'M.Tech', 'Any Postgraduate', 'Any Postgraduate', 'Any Postgraduate', 'Any Postgraduate', 'Any Postgraduate', 'Any Postgraduate', 'Any Postgraduate', 'Any Postgraduate', 'Any Postgraduate', 'Any Postgraduate', 'Any Postgraduate', 'Any Postgraduate', 'Any Postgraduate', 'Any Postgraduate']
# 40

# %%
df["undergraduate"]=undergraduate
df["postgraduate"]=postgraduate

# %%
df.to_csv("C:\\Users\\chaitu\\Desktop\\WebScraping\\Naukri\\Full Stack Development.csv",index=False)
