# %%
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager 
from selenium.webdriver.common.by import By
import pandas as pd
import time

# %% [markdown]
# # Name and Links

# %%
driver=webdriver.Chrome(executable_path="C:\\BrowserDrivers\\chromedriver.exe")
driver.get("https://www.naukri.com/naukri-jobs?glbl_qcrc=1028")
job_elements = driver.find_elements(By.TAG_NAME,'a')
job_desc=[]
for i in job_elements:
    if i.get_attribute('class')=="title ellipsis":
        job_desc.append([i.text,i.get_attribute('href')])
driver.close()
# Out:
# C:\Users\chaitu\AppData\Local\Temp/ipykernel_7304/4042413430.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver=webdriver.Chrome(executable_path="C:\\BrowserDrivers\\chromedriver.exe")

# %%
driver=webdriver.Chrome(executable_path="C:\\BrowserDrivers\\chromedriver.exe")
driver.get("https://www.naukri.com/naukri-jobs-2?glbl_qcrc=1028")
page_2=driver.find_elements(By.TAG_NAME,'a')
for i in page_2:
    if i.get_attribute('class')=="title ellipsis":
        job_desc.append([i.text,i.get_attribute('href')])
driver.close()
# Out:
# C:\Users\chaitu\AppData\Local\Temp/ipykernel_7304/2724432106.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver=webdriver.Chrome(executable_path="C:\\BrowserDrivers\\chromedriver.exe")

# %%
len(job_desc)
# Out:
# 40

# %% [markdown]
# # Work Experience

# %%
# Work-Experience
from selenium.common.exceptions import NoSuchElementException
a=[]
k=0
for i in job_desc:
    driver=webdriver.Chrome(executable_path='C:\\BrowserDrivers\\chromedriver.exe')
    driver.get(i[1])
    try:
        exp_name=driver.find_element(By.CSS_SELECTOR,"div[class='exp'] span")
        a.append(exp_name.text)
    except NoSuchElementException:
        class_name=driver.find_element(By.CLASS_NAME,"slide-meta-exp")
        a.append(class_name.text)
    driver.close()
# Out:
# C:\Users\chaitu\AppData\Local\Temp/ipykernel_7304/2173488271.py:6: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver=webdriver.Chrome(executable_path='C:\\BrowserDrivers\\chromedriver.exe')

# %%
k=0
for i in a:
    job_desc[k].append(i)
    k=k+1

# %% [markdown]
# # Salary

# %%
a=[]
driver=webdriver.Chrome(executable_path='C:\\BrowserDrivers\\chromedriver.exe')
driver.get('https://www.naukri.com/naukri-jobs?glbl_qcrc=1028')
salary=driver.find_elements(By.TAG_NAME,'span')
for i in salary:
    if i.get_attribute('class')=="ellipsis fleft ":
        a.append(i.text)
driver.close()
driver=webdriver.Chrome(executable_path='C:\\BrowserDrivers\\chromedriver.exe')
driver.get('https://www.naukri.com/naukri-jobs-2?glbl_qcrc=1028')
salary=driver.find_elements(By.TAG_NAME,'span')
for i in salary:
    if i.get_attribute('class')=="ellipsis fleft ":
        a.append(i.text)
driver.close()
# Out:
# C:\Users\chaitu\AppData\Local\Temp/ipykernel_7304/3496438066.py:2: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver=webdriver.Chrome(executable_path='C:\\BrowserDrivers\\chromedriver.exe')
# C:\Users\chaitu\AppData\Local\Temp/ipykernel_7304/3496438066.py:9: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver=webdriver.Chrome(executable_path='C:\\BrowserDrivers\\chromedriver.exe')

# %%
driver=webdriver.Chrome(executable_path='C:\\BrowserDrivers\\chromedriver.exe')
driver.get('https://www.naukri.com/naukri-jobs-2?glbl_qcrc=1028')
salary=driver.find_elements(By.TAG_NAME,'span')
for i in salary:
    if i.get_attribute('class')=="ellipsis fleft ":
        a.append(i.text)
driver.close()
# Out:
# C:\Users\chaitu\AppData\Local\Temp/ipykernel_7304/1989322315.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver=webdriver.Chrome(executable_path='C:\\BrowserDrivers\\chromedriver.exe')

# %%
k=0
for i in a:
    job_desc[k].append(i)
    k=k+1

# %% [markdown]
# # Location| Education | KeySkills

# %%
driver=webdriver.Chrome(executable_path="C:\\BrowserDrivers\\chromedriver.exe")
driver.get("https://www.naukri.com/naukri-jobs?glbl_qcrc=1028")
loc_edu_ks=[]
for i in job_desc[:20]:
    driver=webdriver.Chrome(executable_path='C:\\BrowserDrivers\\chromedriver.exe')
    driver.get(i[1])
    try:
        #location
        loc_xpath=driver.find_element(By.XPATH,"//span[@class='location ']")
        #Education
        edu_elements = driver.find_elements(By.CSS_SELECTOR,'div[class="education"] span')
        edu=[i.text for i in edu_elements]
        #keyskill of click and nonclick
        keyskill_click=driver.find_elements(By.XPATH,"//a[@class='chip clickable']")
        keyskill_nonclick=driver.find_elements(By.CSS_SELECTOR,"a[class='chip non-clickable']")
        ks1=[i.text for i in keyskill_click]
        ks2=[i.text for i in keyskill_nonclick]
        ks=ks1+ks2
        loc_edu_ks.append([loc_xpath.text,edu,ks])
    except NoSuchElementException:
        location=driver.find_element(By.CLASS_NAME,"cityLinks")
        edu1=driver.find_element(By.CSS_SELECTOR,"p[class='coPE getUGCourse'] span")
        edu2=driver.find_element(By.CSS_SELECTOR,"p[class='coPE getPGCourse'] span")        
        keys_skills=driver.find_elements(By.CLASS_NAME,'clickable')
        ks=[i.text for i in keys_skills]
        loc_edu_ks.append([location.text,[edu1.text,edu2.text],ks])
    driver.close()
# Out:
# C:\Users\chaitu\AppData\Local\Temp/ipykernel_7304/1401487475.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver=webdriver.Chrome(executable_path="C:\\BrowserDrivers\\chromedriver.exe")
# C:\Users\chaitu\AppData\Local\Temp/ipykernel_7304/1401487475.py:5: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver=webdriver.Chrome(executable_path='C:\\BrowserDrivers\\chromedriver.exe')

# %%
for i in job_desc[20:]:
    driver=webdriver.Chrome(executable_path='C:\\BrowserDrivers\\chromedriver.exe')
    driver.get(i[1])
    try:
        #location
        loc_xpath=driver.find_element(By.XPATH,"//span[@class='location ']")
        #Education
        edu_elements = driver.find_elements(By.CSS_SELECTOR,'div[class="education"] span')
        edu=[i.text for i in edu_elements]
        #keyskill of click and nonclick
        keyskill_click=driver.find_elements(By.XPATH,"//a[@class='chip clickable']")
        keyskill_nonclick=driver.find_elements(By.CSS_SELECTOR,"a[class='chip non-clickable']")
        ks1=[i.text for i in keyskill_click]
        ks2=[i.text for i in keyskill_nonclick]
        ks=ks1+ks2
        loc_edu_ks.append([loc_xpath.text,edu,ks])
    except NoSuchElementException:
        location=driver.find_element(By.CLASS_NAME,"cityLinks")
        edu1=driver.find_element(By.CSS_SELECTOR,"p[class='coPE getUGCourse'] span")
        edu2=driver.find_element(By.CSS_SELECTOR,"p[class='coPE getPGCourse'] span")        
        keys_skills=driver.find_elements(By.CLASS_NAME,'clickable')
        ks=[i.text for i in keys_skills]
        loc_edu_ks.append([location.text,[edu1.text,edu2.text],ks])
    driver.close()
# Out:
# C:\Users\chaitu\AppData\Local\Temp/ipykernel_7304/1310958511.py:2: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver=webdriver.Chrome(executable_path='C:\\BrowserDrivers\\chromedriver.exe')

# %%
loc_edu_ks
# Out:
# [['Bangalore/Bengaluru',
#   ['B.Tech/B.E. in Any Specialization', 'M.Tech in Any Specialization'],
#   ['css', 'Front End', 'Javascript', 'html', 'Angular']],
#  ['Hyderabad/Secunderabad, Ahmedabad, Bangalore/Bengaluru',
#   ['B.Tech/B.E. in Computers', 'MBA/PGDM in Information Technology'],
#   ['Software Development', 'java', 'Android']],
#  ['Hyderabad/Secunderabad, Ahmedabad, Bangalore/Bengaluru',
#   ['B.Tech/B.E. in Computers', 'MBA/PGDM in Information Technology'],
#   ['Software Development', 'java', 'Android']],
#  ['Pune', ['Any Graduate'], ['Svelte.js']],
#  ['Hyderabad/Secunderabad, Bangalore/Bengaluru, Mumbai (All Areas)',
#   ['Any Graduate, Diploma in Any Specialization', 'Any Postgraduate'],
#   ['Java',
#    'Software Testing',
#    'Devops',
#    'Software Development',
#    'Python',
#    'C++',
#    'Cyber Security',
#    'SAP',
#    'C',
#    'Data Science',
#    'Software Developer',
#    'Linux',
#    'Django',
#    'Cloud',
#    'software engineer',
#    'Software',
#    'React.Js',
#    'Oracle',
#    'Software Programming',
#    'Information Technology',
#    'Salesforce',
#    'Dotnet Development',
#    'Fullstack Development']],
#  ['Noida( Sector-62 Noida )',
#   ['Any Graduate, B.Tech/B.E. in Any Specialization',
#    'MCA in Any Specialization'],
#   ['CSS',
#    'OOPS',
#    'HTML',
#    'Javascript',
#    'Java',
#    'Node.Js',
#    'JQuery',
#    'SQL',
#    'Agile Methodology',
#    'GIT',
#    'Bootstrap',
#    'MongoDB',
#    'React.Js',
#    'AWS',
#    'Web Development',
#    'Angular',
#    'Jenkins Ci',
#    'Expresjs']],
#  ['Bangalore/Bengaluru',
#   ['B.Sc in Any Specialization'],
#   ['security', 'java', 'software']],
#  ['Bangalore/Bengaluru',
#   ['B.Tech/B.E. in Any Specialization', 'Any Postgraduate'],
#   ['PL/SQL',
#    'Performance tuning',
#    'Performance engineering',
#    'Agile',
#    'Troubleshooting',
#    'Oracle',
#    'SDLC']],
#  ['Bangalore/Bengaluru',
#   ['B.Tech/B.E. in Any Specialization',
#    'MCA in Any Specialization,MBA/PGDM in Any Specialization,M.Tech in Any Specialization'],
#   ['SAP ABAP',
#    'ODATA',
#    'SAP Fiori',
#    'SAP S/4 HANA',
#    'Adobe Forms',
#    'Debugging',
#    'Agile',
#    'Test planning']],
#  ['Bangalore/Bengaluru',
#   ['B.Tech/B.E. in Any Specialization', 'Any Postgraduate'],
#   ['Power BI',
#    'Performance engineering',
#    'SSRS',
#    'agile methodologies',
#    'MSBI',
#    'SSIS',
#    'SDLC']],
#  ['Bangalore/Bengaluru',
#   ['BCA in Computers,B.Tech/B.E. in Computers,B.Sc in Computers',
#    'MCA in Any Specialization,M.Tech in Any Specialization,MS/M.Sc(Science) in Any Specialization'],
#   ['IT Consulting',
#    'functional designs',
#    'UI',
#    'solution design',
#    'ReactJS',
#    'Consulting']],
#  ['Bangalore/Bengaluru',
#   ['BCA in Computers,B.Com in Commerce,B.Tech/B.E. in Computers,B.Sc in Computers',
#    'MCA in Any Specialization,MS/M.Sc(Science) in Any Specialization,M.Tech in Any Specialization'],
#   ['Angular',
#    'Angular JS',
#    'Java',
#    'Oracle OSS',
#    'agile methodologies',
#    'test cases',
#    'performance engineering',
#    'SDLC']],
#  ['Bangalore/Bengaluru',
#   ['B.Tech/B.E. in Any Specialization', 'Any Postgraduate'],
#   ['COGNOS',
#    'Agile methodologies',
#    'Performance engineering',
#    'Cognos TM1',
#    'SDLC']],
#  ['Bangalore/Bengaluru',
#   ['B.Sc in Any Specialization,B.Tech/B.E. in Any Specialization,BCA in Any Specialization',
#    'MBA/PGDM in Any Specialization,MCA in Any Specialization,MS/M.Sc(Science) in Any Specialization,M.Tech in Any Specialization'],
#   ['Cloud Platform',
#    'Team management',
#    'Project management',
#    'Software configuration management',
#    'Apache Kafka',
#    'Opensource',
#    'Springboot',
#    'Microservices']],
#  ['Bangalore/Bengaluru',
#   ['B.Tech/B.E. in Any Specialization', 'Any Postgraduate'],
#   ['IT Testing', 'selenium', 'SOA', 'automation testing', 'API testing']],
#  ['Bangalore/Bengaluru',
#   ['B.Tech/B.E. in Any Specialization', 'Any Postgraduate'],
#   ['ReactJs', 'React redux', 'React native', 'agile']],
#  ['Bangalore/Bengaluru',
#   ['B.Tech/B.E. in Any Specialization', 'Any Postgraduate'],
#   ['NodeJs', 'performance engineering', 'agile', 'SDLC']],
#  ['Bangalore/Bengaluru',
#   ['B.Tech/B.E. in Any Specialization', 'Any Postgraduate'],
#   ['Java', 'performance engineering', 'Springboot', 'SDLC', 'microservices']],
#  ['Bangalore/Bengaluru',
#   ['Any Graduate', 'Any Postgraduate'],
#   ['client solution',
#    'Lead generation',
#    'Communication Skills',
#    'Market intelligence',
#    'Presales',
#    'Bid management',
#    'presentation Skills',
#    'Logistics']],
#  ['Bangalore/Bengaluru',
#   ['Any Graduate'],
#   ['Algorithms', 'Data Structures And Algorithms']],
#  ['Noida, Mumbai, Pune, Chennai, Bangalore/Bengaluru',
#   ['B.Tech/B.E. in Electronics/Telecommunication, Computers',
#    'MCA in Computers'],
#   ['Salesforce',
#    'Certified',
#    'Aura',
#    'Lightning',
#    'Salesforce Sales Cloud',
#    'Salesforce Service Cloud',
#    'Salesforce Community Cloud',
#    'Lwc']],
#  ['Hyderabad/Secunderabad',
#   ['B.Tech/B.E. in Any Specialization', 'Any Postgraduate'],
#   ['Software architecture',
#    'Jenkins',
#    'RedHat OpenStack',
#    'Terraform',
#    'GitHub',
#    'Ansible',
#    'AWS',
#    'Kubernetes']],
#  ['Hyderabad/Secunderabad',
#   ['B.Tech/B.E. in Any Specialization', 'Any Postgraduate'],
#   ['Angular',
#    'Markup Language',
#    'UI',
#    'Agile methodologies',
#    'Estimation methodologies',
#    'Analytical',
#    'Software quality assurance',
#    'SOLID design',
#    'Project life cycle',
#    'Testing']],
#  ['Hubli',
#   ['BCA in Computers,B.Tech/B.E. in Any Specialization',
#    'MS/M.Sc(Science) in Any Specialization,MCA in Computers,M.Tech in Any Specialization'],
#   ['Aerospace Engineering',
#    'Embedded Software',
#    'Aero Engine Design',
#    'Aircraft Maintenance',
#    'UGNX']],
#  ['Pune',
#   ['B.Tech/B.E. in Any Specialization', 'Any Postgraduate'],
#   ['Java',
#    'Docker',
#    'Debugging',
#    'Agile',
#    'Test planning',
#    'Spring boot',
#    'Devops',
#    'AWS',
#    'Python']],
#  ['Coimbatore',
#   ['B.Tech/B.E. in Any Specialization', 'Any Postgraduate'],
#   ['NodeJS', 'UI', 'Software Engineering', 'Application development', 'SDLC']],
#  ['Pune',
#   ['BCA in Any Specialization,B.Tech/B.E. in Any Specialization',
#    'MS/M.Sc(Science) in Any Specialization,MCA in Any Specialization,M.Tech in Any Specialization'],
#   ['Android',
#    'Analytical Skills',
#    'agile methodologies',
#    'Test planning',
#    'Software quality assurance',
#    'Mobile Development Platform']],
#  ['Gurgaon/Gurugram',
#   ['B.Tech/B.E. in Any Specialization', 'Any Postgraduate'],
#   ['ReactJs',
#    'React redux',
#    'Testing tools',
#    'React native',
#    'Debugging',
#    'Agile',
#    'Test planning',
#    'Application development',
#    'Software quality assurance']],
#  ['Pune',
#   ['B.Tech/B.E. in Any Specialization,B.Sc in Any Specialization,BCA in Any Specialization',
#    'MCA in Any Specialization,M.Tech in Any Specialization,MS/M.Sc(Science) in Any Specialization'],
#   ['PHP',
#    'UI',
#    'Debugging',
#    'agile methodologies',
#    'Test planning',
#    'Software quality assurance']],
#  ['Indore',
#   ['B.Tech/B.E. in Any Specialization', 'Any Postgraduate'],
#   ['NodeJs',
#    'Testing tools',
#    'Analytical',
#    'Technology Lead',
#    'Debugging',
#    'Agile',
#    'Manager Technology',
#    'Test planning',
#    'Issue resolution',
#    'Application development',
#    'Software quality assurance']],
#  ['Chennai',
#   ['B.Tech/B.E. in Any Specialization,B.Sc in Any Specialization',
#    'M.Tech in Any Specialization,MS/M.Sc(Science) in Any Specialization'],
#   ['Java',
#    'Debugging',
#    'JDBC',
#    'Test planning',
#    'Application development',
#    'Spring',
#    'Software quality assurance']],
#  ['Gurgaon/Gurugram',
#   ['B.Tech/B.E. in Any Specialization', 'Any Postgraduate'],
#   ['Angular', 'UI', 'agile methodologies', 'performance engineering', 'SDLC']],
#  ['Mohali',
#   ['B.Tech/B.E. in Any Specialization', 'Any Postgraduate'],
#   ['NodeJs', 'UI', 'Software Engineering', 'Operating System', 'SDLC']],
#  ['Chennai',
#   ['B.Tech/B.E. in Any Specialization',
#    'MS/M.Sc(Science) in Any Specialization,MCA in Any Specialization'],
#   ['ReactJS',
#    'Performance tuning',
#    'Markup Language',
#    'UI',
#    'Architectural design patterns',
#    'Service Oriented Architecture',
#    'SDLC']],
#  ['Bhubaneswar',
#   ['B.Tech/B.E. in Any Specialization', 'Any Postgraduate'],
#   ['Systems Engineering',
#    'React redux',
#    'Software Engineering',
#    'ReactJS',
#    'React native',
#    'SDLC',
#    'Test Cases']],
#  ['Mangaluru/Mangalore',
#   ['B.Tech/B.E. in Any Specialization', 'Any Postgraduate'],
#   ['NodeJS',
#    'Markup Language',
#    'UI',
#    'software quality assurance principles',
#    'agile methodologies',
#    'SOLID']],
#  ['Gurgaon/Gurugram',
#   ['B.Tech/B.E. in Any Specialization', 'Any Postgraduate'],
#   ['NodeJs',
#    'Markup Language',
#    'UI',
#    'Agile methodologies',
#    'Performance engineering',
#    'SDLC']],
#  ['Indore',
#   ['B.Tech/B.E. in Any Specialization', 'Any Postgraduate'],
#   ['IT Testing',
#    'Jenkins',
#    'Automation testing',
#    'selenium',
#    'manual testing',
#    'agile',
#    'SDLC']],
#  ['Pune',
#   ['B.Tech/B.E. in Any Specialization', 'Any Postgraduate'],
#   ['Windows Administration',
#    'VMWare',
#    'Project management',
#    'Windows',
#    'Wintel',
#    'SDLC',
#    'Quality management']],
#  ['Chandigarh',
#   ['B.Tech/B.E. in Any Specialization', 'Any Postgraduate'],
#   ['Angular', 'Designing', 'Markup language', 'SDLC']]]

# %%
k=0
for i in loc_edu_ks:
    job_desc[k].append(i[0])
    job_desc[k].append(i[1])
    job_desc[k].append(i[2])
    k=k+1

# %%
import pandas as pd
df=pd.DataFrame(job_desc ,columns=["Name","Link","Work Experience","Salary","Location","Education","KeySkills"])
df
# Out:
#                                                  Name  \
# 0                   Lead Front End Developer- Angular
# 1                                  Software Developer
# 2                              Software Developer paf
# 3   Opportunity For UI Developer with Svelte.js In...
# 4           Software Engineer, Developer / Programmer
# 5                                  Software Developer
# 6        Java Developer II (Naukri Test Do Not Apply)
# 7                             Oracle PL/SQL Developer
# 8                                  SAP ABAP Developer
# 9                             Power BI/MSBI Developer
# 10                         IT Consulting Professional
# 11                                  Angular Developer
# 12                                   Cognos Developer
# 13                                    Kafka Developer
# 14                            IT Testing professional
# 15                          Technology Lead - ReactJs
# 16                          Systems Engineer - NodeJs
# 17                          Technology Analyst - Java
# 18                       Client Solution Lead/Manager
# 19                                    C/C++ Developer
# 20                        Salesforce Developers/Leads
# 21  Software Architect - Ansible / Terraform / Kub...
# 22                          Technology Lead - Angular
# 23                                 Aerospace Engineer
# 24                                     Java Developer
# 25                      Sr. Systems Engineer - NodeJS
# 26                           IT Delivery Professional
# 27                          Technology Lead - ReactJs
# 28                                      PHP Developer
# 29                           Technology Lead - NodeJs
# 30                                          Java Lead
# 31                         Systems Engineer - Angular
# 32                      Sr. Systems Engineer - NodeJs
# 33                                 React JS Architect
# 34                    Sr. Systems Engineer - React JS
# 35                           Technology Lead - NodeJS
# 36                          Systems Engineer - NodeJs
# 37                            IT Testing professional
# 38                              Windows Administrator
# 39                       Technology Analyst - Angular
#
#                                                  Link  \
# 0   https://www.naukri.com/job-listings-lead-front...
# 1   https://www.naukri.com/job-listings-software-d...
# 2   https://www.naukri.com/job-listings-software-d...
# 3   https://www.naukri.com/job-listings-opportunit...
# 4   https://www.naukri.com/job-listings-software-e...
# 5   https://www.naukri.com/job-listings-software-d...
# 6   https://www.naukri.com/job-listings-java-devel...
# 7   https://www.naukri.com/job-listings-oracle-pl-...
# 8   https://www.naukri.com/job-listings-sap-abap-d...
# 9   https://www.naukri.com/job-listings-power-bi-m...
# 10  https://www.naukri.com/job-listings-it-consult...
# 11  https://www.naukri.com/job-listings-angular-de...
# 12  https://www.naukri.com/job-listings-cognos-dev...
# 13  https://www.naukri.com/job-listings-kafka-deve...
# 14  https://www.naukri.com/job-listings-it-testing...
# 15  https://www.naukri.com/job-listings-technology...
# 16  https://www.naukri.com/job-listings-systems-en...
# 17  https://www.naukri.com/job-listings-technology...
# 18  https://www.naukri.com/job-listings-client-sol...
# 19  https://www.naukri.com/job-listings-c-c-develo...
# 20  https://www.naukri.com/job-listings-salesforce...
# 21  https://www.naukri.com/job-listings-software-a...
# 22  https://www.naukri.com/job-listings-technology...
# 23  https://www.naukri.com/job-listings-aerospace-...
# 24  https://www.naukri.com/job-listings-java-devel...
# 25  https://www.naukri.com/job-listings-sr-systems...
# 26  https://www.naukri.com/job-listings-it-deliver...
# 27  https://www.naukri.com/job-listings-technology...
# 28  https://www.naukri.com/job-listings-php-develo...
# 29  https://www.naukri.com/job-listings-technology...
# 30  https://www.naukri.com/job-listings-java-lead-...
# 31  https://www.naukri.com/job-listings-systems-en...
# 32  https://www.naukri.com/job-listings-sr-systems...
# 33  https://www.naukri.com/job-listings-react-js-a...
# 34  https://www.naukri.com/job-listings-sr-systems...
# 35  https://www.naukri.com/job-listings-technology...
# 36  https://www.naukri.com/job-listings-systems-en...
# 37  https://www.naukri.com/job-listings-it-testing...
# 38  https://www.naukri.com/job-listings-windows-ad...
# 39  https://www.naukri.com/job-listings-technology...
#
#                        Work Experience            Salary  \
# 0                          3 - 6 years     Not disclosed
# 1                          2 - 6 years       3-6 Lacs PA
# 2                          2 - 6 years       3-6 Lacs PA
# 3                          5 - 9 years     Not disclosed
# 4                          0 - 5 years       3-8 Lacs PA
# 5                          0 - 2 years  60,000-3 Lacs PA
# 6                         8 - 12 years      7-16 Lacs PA
# 7    From 3 to 5 year(s) of experience     Not disclosed
# 8    From 3 to 5 year(s) of experience     Not disclosed
# 9    From 3 to 5 year(s) of experience     Not disclosed
# 10   From 2 to 6 year(s) of experience     Not disclosed
# 11   From 3 to 5 year(s) of experience     Not disclosed
# 12   From 3 to 5 year(s) of experience     Not disclosed
# 13   From 5 to 7 year(s) of experience     Not disclosed
# 14   From 4 to 7 year(s) of experience     Not disclosed
# 15   From 5 to 8 year(s) of experience     Not disclosed
# 16   From 1 to 2 year(s) of experience     Not disclosed
# 17   From 3 to 5 year(s) of experience     Not disclosed
# 18   From 2 to 6 year(s) of experience     Not disclosed
# 19                         5 - 8 years     Not disclosed
# 20                        6 - 11 years     Not disclosed
# 21  From 7 to 10 year(s) of experience     Not disclosed
# 22   From 5 to 8 year(s) of experience     Not disclosed
# 23   From 5 to 7 year(s) of experience     15-25 Lacs PA
# 24   From 5 to 7 year(s) of experience     15-30 Lacs PA
# 25   From 2 to 3 year(s) of experience     Not disclosed
# 26   From 5 to 7 year(s) of experience     Not disclosed
# 27   From 5 to 8 year(s) of experience     Not disclosed
# 28   From 5 to 7 year(s) of experience     Not disclosed
# 29   From 5 to 8 year(s) of experience     Not disclosed
# 30   From 5 to 9 year(s) of experience     Not disclosed
# 31   From 1 to 2 year(s) of experience     Not disclosed
# 32   From 2 to 3 year(s) of experience     Not disclosed
# 33  From 8 to 10 year(s) of experience     Not disclosed
# 34   From 2 to 3 year(s) of experience     Not disclosed
# 35   From 5 to 8 year(s) of experience     Not disclosed
# 36   From 1 to 2 year(s) of experience     Not disclosed
# 37   From 5 to 7 year(s) of experience     Not disclosed
# 38   From 3 to 5 year(s) of experience     Not disclosed
# 39   From 3 to 5 year(s) of experience     Not disclosed
#
#                                              Location  \
# 0                                 Bangalore/Bengaluru
# 1   Hyderabad/Secunderabad, Ahmedabad, Bangalore/B...
# 2   Hyderabad/Secunderabad, Ahmedabad, Bangalore/B...
# 3                                                Pune
# 4   Hyderabad/Secunderabad, Bangalore/Bengaluru, M...
# 5                            Noida( Sector-62 Noida )
# 6                                 Bangalore/Bengaluru
# 7                                 Bangalore/Bengaluru
# 8                                 Bangalore/Bengaluru
# 9                                 Bangalore/Bengaluru
# 10                                Bangalore/Bengaluru
# 11                                Bangalore/Bengaluru
# 12                                Bangalore/Bengaluru
# 13                                Bangalore/Bengaluru
# 14                                Bangalore/Bengaluru
# 15                                Bangalore/Bengaluru
# 16                                Bangalore/Bengaluru
# 17                                Bangalore/Bengaluru
# 18                                Bangalore/Bengaluru
# 19                                Bangalore/Bengaluru
# 20  Noida, Mumbai, Pune, Chennai, Bangalore/Bengaluru
# 21                             Hyderabad/Secunderabad
# 22                             Hyderabad/Secunderabad
# 23                                              Hubli
# 24                                               Pune
# 25                                         Coimbatore
# 26                                               Pune
# 27                                   Gurgaon/Gurugram
# 28                                               Pune
# 29                                             Indore
# 30                                            Chennai
# 31                                   Gurgaon/Gurugram
# 32                                             Mohali
# 33                                            Chennai
# 34                                        Bhubaneswar
# 35                                Mangaluru/Mangalore
# 36                                   Gurgaon/Gurugram
# 37                                             Indore
# 38                                               Pune
# 39                                         Chandigarh
#
#                                             Education  \
# 0   [B.Tech/B.E. in Any Specialization, M.Tech in ...
# 1   [B.Tech/B.E. in Computers, MBA/PGDM in Informa...
# 2   [B.Tech/B.E. in Computers, MBA/PGDM in Informa...
# 3                                      [Any Graduate]
# 4   [Any Graduate, Diploma in Any Specialization, ...
# 5   [Any Graduate, B.Tech/B.E. in Any Specializati...
# 6                        [B.Sc in Any Specialization]
# 7   [B.Tech/B.E. in Any Specialization, Any Postgr...
# 8   [B.Tech/B.E. in Any Specialization, MCA in Any...
# 9   [B.Tech/B.E. in Any Specialization, Any Postgr...
# 10  [BCA in Computers,B.Tech/B.E. in Computers,B.S...
# 11  [BCA in Computers,B.Com in Commerce,B.Tech/B.E...
# 12  [B.Tech/B.E. in Any Specialization, Any Postgr...
# 13  [B.Sc in Any Specialization,B.Tech/B.E. in Any...
# 14  [B.Tech/B.E. in Any Specialization, Any Postgr...
# 15  [B.Tech/B.E. in Any Specialization, Any Postgr...
# 16  [B.Tech/B.E. in Any Specialization, Any Postgr...
# 17  [B.Tech/B.E. in Any Specialization, Any Postgr...
# 18                   [Any Graduate, Any Postgraduate]
# 19                                     [Any Graduate]
# 20  [B.Tech/B.E. in Electronics/Telecommunication,...
# 21  [B.Tech/B.E. in Any Specialization, Any Postgr...
# 22  [B.Tech/B.E. in Any Specialization, Any Postgr...
# 23  [BCA in Computers,B.Tech/B.E. in Any Specializ...
# 24  [B.Tech/B.E. in Any Specialization, Any Postgr...
# 25  [B.Tech/B.E. in Any Specialization, Any Postgr...
# 26  [BCA in Any Specialization,B.Tech/B.E. in Any ...
# 27  [B.Tech/B.E. in Any Specialization, Any Postgr...
# 28  [B.Tech/B.E. in Any Specialization,B.Sc in Any...
# 29  [B.Tech/B.E. in Any Specialization, Any Postgr...
# 30  [B.Tech/B.E. in Any Specialization,B.Sc in Any...
# 31  [B.Tech/B.E. in Any Specialization, Any Postgr...
# 32  [B.Tech/B.E. in Any Specialization, Any Postgr...
# 33  [B.Tech/B.E. in Any Specialization, MS/M.Sc(Sc...
# 34  [B.Tech/B.E. in Any Specialization, Any Postgr...
# 35  [B.Tech/B.E. in Any Specialization, Any Postgr...
# 36  [B.Tech/B.E. in Any Specialization, Any Postgr...
# 37  [B.Tech/B.E. in Any Specialization, Any Postgr...
# 38  [B.Tech/B.E. in Any Specialization, Any Postgr...
# 39  [B.Tech/B.E. in Any Specialization, Any Postgr...
#
#                                             KeySkills
# 0         [css, Front End, Javascript, html, Angular]
# 1               [Software Development, java, Android]
# 2               [Software Development, java, Android]
# 3                                         [Svelte.js]
# 4   [Java, Software Testing, Devops, Software Deve...
# 5   [CSS, OOPS, HTML, Javascript, Java, Node.Js, J...
# 6                          [security, java, software]
# 7   [PL/SQL, Performance tuning, Performance engin...
# 8   [SAP ABAP, ODATA, SAP Fiori, SAP S/4 HANA, Ado...
# 9   [Power BI, Performance engineering, SSRS, agil...
# 10  [IT Consulting, functional designs, UI, soluti...
# 11  [Angular, Angular JS, Java, Oracle OSS, agile ...
# 12  [COGNOS, Agile methodologies, Performance engi...
# 13  [Cloud Platform, Team management, Project mana...
# 14  [IT Testing, selenium, SOA, automation testing...
# 15        [ReactJs, React redux, React native, agile]
# 16     [NodeJs, performance engineering, agile, SDLC]
# 17  [Java, performance engineering, Springboot, SD...
# 18  [client solution, Lead generation, Communicati...
# 19       [Algorithms, Data Structures And Algorithms]
# 20  [Salesforce, Certified, Aura, Lightning, Sales...
# 21  [Software architecture, Jenkins, RedHat OpenSt...
# 22  [Angular, Markup Language, UI, Agile methodolo...
# 23  [Aerospace Engineering, Embedded Software, Aer...
# 24  [Java, Docker, Debugging, Agile, Test planning...
# 25  [NodeJS, UI, Software Engineering, Application...
# 26  [Android, Analytical Skills, agile methodologi...
# 27  [ReactJs, React redux, Testing tools, React na...
# 28  [PHP, UI, Debugging, agile methodologies, Test...
# 29  [NodeJs, Testing tools, Analytical, Technology...
# 30  [Java, Debugging, JDBC, Test planning, Applica...
# 31  [Angular, UI, agile methodologies, performance...
# 32  [NodeJs, UI, Software Engineering, Operating S...
# 33  [ReactJS, Performance tuning, Markup Language,...
# 34  [Systems Engineering, React redux, Software En...
# 35  [NodeJS, Markup Language, UI, software quality...
# 36  [NodeJs, Markup Language, UI, Agile methodolog...
# 37  [IT Testing, Jenkins, Automation testing, sele...
# 38  [Windows Administration, VMWare, Project manag...
# 39        [Angular, Designing, Markup language, SDLC]

# %%
df.to_csv("C:\\Users\\chaitu\\Desktop\\WebScraping\\Software Developer.csv",columns=["Name","Link","Work Experience","Salary","Location","Education","KeySkills"],index=False)
